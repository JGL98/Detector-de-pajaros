# %%
import pandas as pd
import numpy as np
import pprint as ppr
import tqdm

# %%
import glob

# %% [markdown]
# # Lectura de datos

# %%
files=glob.glob("*.txt")

# %%
data=pd.DataFrame(files,columns=["publications"])

# %%
data
# Out:
#   publications
# 0    pub_1.txt
# 1   pub_10.txt
# 2    pub_2.txt
# 3    pub_3.txt
# 4    pub_4.txt
# 5    pub_5.txt
# 6    pub_6.txt
# 7    pub_7.txt
# 8    pub_8.txt
# 9    pub_9.txt

# %% [markdown]
# Ejemplo de una publicación:

# %%
open(data.publications[1],"r",encoding="utf-8").read()
# Out:
# '28th November, 2020 ---\nhttps://www.trevorsbirding.com/ ---\n\nResident nesting Galahs\nI live on the edge of the rural city of Murray Bridge which is about an hour’s drive from Adelaide, South Australia. We are blessed to have a variety of parrots, cockatoos and lorikeets in the region. One of the common birds in this family is the Galah. I am sure that if I took a census of this species over a whole year, there would be very few days pass without seeing at least a handful of these lovely parrots either resting in the trees in my garden, or flying overhead. On occasions, I have even seen flocks of many dozens through to many hundreds. They are a very common species in this area.\nEasy birding\nThe photos shown in today’s post were all taken in my garden and all within a few minutes of each other. This hollow is in an old-growth mallee tree within about twenty metres of my back veranda. I have a comfortable chair located there and I enjoy sitting there reading – or just watching the birds all around. It is very relaxing and quite lovely that the local, resident birds just go about their activities while totally ignoring me. It also makes photography easy.\nNesting attempts\nA pair of Galahs have been working at this hollow for some years. Then, about four years ago they started putting fresh eucalypt leaves in the hollow. I eagerly anticipated a nesting attempt but they abandoned their quest. About once or twice a day they would sit at the opening of the hollow and screech loudly into the hollow – then fly away.\n\nStrange, I thought.\n\nAn interloper takes over\nA few days later I discovered the reason why they hadn’t successfully nested in the hollow. I saw a Brush-tailed Possum coming out of the hollow. It had evicted the Galahs from their home. After some months I guess that the possum had moved on elsewhere. In fact, I haven’t seen one or heard one on the roof for several years now. So the Galahs returned to their home.\n\nSuccess at last\nDuring late winter last year they again started working on the hollow. During the next month or so they successfully laid eggs and raised their chicks which later fledged. This year they have again been successful. I didn’t manage to get a photo of this year’s chicks because they flew off before I could get a shot. Instead, I have included below a photo of one of the chicks from last year’s brood.\n\nA few days after the two chicks fledged, they were precariously hanging on to the branches of the trees nearby, along with about a dozen other chicks from other parents. Most of them were calling to be fed, and as the parents came in to feed them I had a very noisy Galah nursery in my garden.'

# %% [markdown]
# Se puede ver cómo se adjunta la fecha y el enlace del blog de la publicación.

# %% [markdown]
# # Encontrar los pájaros

# %% [markdown]
# ## Primera opción: Filtrar entidades con spacy (finalmente descartado)

# %%
from spacy import displacy
import en_core_web_sm
import string

# %% [markdown]
# Spacy no tiene etiquetas correspondientes a especies de animales. La idea de la siguiente función es tokenizar cada publicación quedándonos únicamente con las entidades que no estén en el filtro definido como *filter_*. Como veremos más adelante, esto supone perder gran parte de la información de interés, por lo que finalmente se optó por otro método (véase siguiente apartado).

# %%
def entities(file):

    text=open(file,"r",encoding="utf-8").read().split("---")[-1]
    #cargamos el tockenizador
    nlp = en_core_web_sm.load()

    #eliminamos números y signos de puntuación
    text=text.translate(str.maketrans("","",string.punctuation)).translate(str.maketrans("","",string.digits))

    #tockenizamos el texto
    train = nlp(text)

    #definimos un conjunto
    ent_list= set()



    filter_=["DATE","FAC","GPE","CARDINAL","TIME","QUANTITY","LOC","WORK_OF_ART","NORP","ORDINAL"]
    
    for entity in tqdm.tqdm(train.ents):
        #filtramos las entidades de interés       
        if entity.label_ not in filter_:
            #ent_list.add(entity.label_+": "+entity.text)
            ent_list.add(entity.text)
    return(ent_list)

# %%
ents=data.apply(np.vectorize(entities),axis=1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 32/32 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 32032.87it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 13987.67it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 51/51 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 51/51 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 165/165 [00:00<00:00, 165051.31it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 165/165 [00:00<00:00, 160757.30it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 98/98 [00:00<00:00, 98030.48it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 98/98 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 12177.99it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<?, ?it/s]

# %%
for i in range(0,9):
    print("-"*20)
    print(data.publications[i])
    print(" ")
    print(ents[i])
# Out:
# --------------------
# pub_1.txt
#
# [{'the Nisqually National Wildlife Refuge on  March  This'}]
# --------------------
# pub_10.txt
#
# [{'Adelaide South Australia', 'fed', 'noisy Galah', 'Success', 'Galahs'}]
# --------------------
# pub_2.txt
#
# [{'Nick', 'Madeira', 'THWACK', 'Canon'}]
# --------------------
# pub_3.txt
#
# [{'Practice', 'Canon', 'Ill'}]
# --------------------
# pub_4.txt
#
# [{'GREAT CORMORANT LITTLE', 'SURF', 'eBird', 'GREAT', 'Robin', 'Matt Bell', 'Lighthouse', 'ENE', 'Egrets', 'American Bittern', 'Andy Griswold', 'Common', 'Kittiwake', 'Jason Rieger Phil Rusch', 'Shorebirds', 'Phil', 'Luke Tiller', 'VEERY', 'the Milford Point BW Surf Scopers'}]
# --------------------
# pub_5.txt
#
# [{'Bispo', 'Mental', 'Balearic', 'Castro Verde', 'Sylvia', 'Those Balearic Shearwaters', 'Connecticut Audubon Society’s EcoTravel', 'American Robin', 'The Ria de Alvor', 'Mecca of Cape Cod', 'United', 'Lisbon Sagres', 'Atlanticbreeding', 'Ria de Alvor', 'PDF', 'United Airlines', 'LAX', 'Cabo de São Vicente', 'Scopoli', 'Redlegged Thrush', 'the Ria de Alvor', 'Cory', 'HEN HARRIER EURASIAN SPARROWHAWK RED KITE COMMON BUZZARD EURASIAN KESTREL', 'Mission', 'Cabranosa', 'RUPPELL', 'Sagres', 'SW', 'Lagoa', 'Euro', 'Rufousbacked Robin Taiwan Thrush', 'Unsure', 'Faro', 'CINEREOUS', 'BLACKHEADED', 'Shorebirds', 'Turdus', 'Algarve', 'Cancun', 'Mar Ilimitado', 'GREAT SKUAS', 'Cabo', 'Portimao', 'MEDITERRANEAN AUDOUIN’S'}]
# --------------------
# pub_6.txt
#
# [{'COLLARED INCA', 'Mirador Pico de Hoz', 'SURF', 'Boo', 'the BLUEHEADED PARROTS', 'PERUVIAN Killer', 'Amazonia Lodge', 'HUMBOLDT PENGUIN', 'Amazon', 'Pucusana', 'REDLEGGED CORMORANT', 'Puerto Viejo', 'Isla Pucusana', 'GREBE', 'CockoftheRock Lodge', 'hummingbird', 'GREAT GREBES', 'Jory Teltser', 'Sidebyside GREEN HONEYCREEPER', 'GRAY', 'the Humboldt Current', 'Jory', 'LADDERWINGED NIGHTJAR', 'SOLITARY', 'Peru Friend', 'Puna Plover', 'Backtoback', 'Wayqecha Biological Station', 'ASHCOLORED CUCKOO'}]
# --------------------
# pub_7.txt
#
# [{'New Holland Honeyeaters', 'Rainbow Lorikeet', 'Musk Lorikeet', 'Purplecrowned Lorikeets', 'Collared Sparrowhawk', 'House Sparrows'}]
# --------------------
# pub_8.txt
#
# [{'Lovebird'}]

# %% [markdown]
# ### Extraer las especies de Dbpedia

# %% [markdown]
# Ahora con Sparql extraemos todas las entradas en la base de datos *dbo* que tengan la etiqueta *dbo: Bird*.

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pprint as ppr

# %%
import spacy


nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# Contamos el número de resultados:

# %%
sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setQuery("""

PREFIX dbo:<http://dbpedia.org/ontology/>

SELECT (COUNT(*) AS ?count) WHERE {
# ?x a dbo:Bird .
# ?x rdfs:label ?label .

FILTER (lang(?label) = 'en') 
}
""")
sparql.setReturnFormat(JSON)
ret = sparql.queryAndConvert()
n_results=float(ret["results"]["bindings"][0]["count"]["value"])

# %% [markdown]
# Extraemos todas las entradas y sus sinónimos (si es que los tienen) y los guardamos en un diccionario junto a su enlace a la dbpedia. Nótese que al ser una consulta bastante pesada, se ha de hacer por tramos:

# %%
jump=3000
lim=jump
offset=lim-jump

sparql = SPARQLWrapper("http://dbpedia.org/sparql")

species={}
while lim<n_results+jump:

    print(len(species))
    
    sparql.setQuery("""

    PREFIX dbo:<http://dbpedia.org/ontology/>

    SELECT * WHERE {
    # ?x a dbo:Bird .
    # ?x rdfs:label ?label .
    OPTIONAL{?x dbp:synonyms ?synonyms .}

    FILTER (lang(?label) = 'en') 
    }

    ORDER BY ?label
    LIMIT """+str(lim)+"""
    OFFSET """+str(offset))
    
    sparql.setReturnFormat(JSON)
    ret = sparql.queryAndConvert()

    for r in ret["results"]["bindings"]:
        
        species[r["label"]["value"].lower()]=[r["x"]["value"]]
        
        try:
            synonyms=r["synonyms"]["value"].split("\n")

            synonyms=[synonym.replace("*","") for synonym in synonyms]
            
            for synonym in synonyms:
                
                species[synonym.lower()]=[r["x"]["value"]]
                
            
        except:
            pass
        
    lim += jump
    offset += jump
# Out:
# 0
# 4273
# 12529
# 16286

# %%
species
# Out:
# {'1978 atlanta falcons season': ['http://dbpedia.org/resource/1978_Atlanta_Falcons_season'],
#  '1979 atlanta falcons season': ['http://dbpedia.org/resource/1979_Atlanta_Falcons_season'],
#  '1985–86 pittsburgh penguins season': ['http://dbpedia.org/resource/1985–86_Pittsburgh_Penguins_season'],
#  '1986–87 pittsburgh penguins season': ['http://dbpedia.org/resource/1986–87_Pittsburgh_Penguins_season'],
#  '1987–88 pittsburgh penguins season': ['http://dbpedia.org/resource/1987–88_Pittsburgh_Penguins_season'],
#  '1991–92 pittsburgh penguins season': ['http://dbpedia.org/resource/1991–92_Pittsburgh_Penguins_season'],
#  '1993–94 pittsburgh penguins season': ['http://dbpedia.org/resource/1993–94_Pittsburgh_Penguins_season'],
#  '2001–02 mighty ducks of anaheim season': ['http://dbpedia.org/resource/2001–02_Mighty_Ducks_of_Anaheim_season'],
#  '2002–03 mighty ducks of anaheim season': ['http://dbpedia.org/resource/2002–03_Mighty_Ducks_of_Anaheim_season'],
#  '2002–03 pittsburgh penguins season': ['http://dbpedia.org/resource/2002–03_Pittsburgh_Penguins_season'],
#  '2011 wisconsin act 10': ['http://dbpedia.org/resource/2011_Wisconsin_Act_10'],
#  '7.5 cm kwk 42': ['http://dbpedia.org/resource/7.5_cm_KwK_42'],
#  "abbott's babbler": ["http://dbpedia.org/resource/Abbott's_babbler"],
#  'trichastoma abbotti': ["http://dbpedia.org/resource/Abbott's_babbler"],
#  'turdinus abbotti': ["http://dbpedia.org/resource/Abbott's_babbler"],
#  "abbott's booby": ["http://dbpedia.org/resource/Abbott's_booby"],
#  'sula abbotti': ["http://dbpedia.org/resource/Abbott's_booby"],
#  'abd al-kuri sparrow': ['http://dbpedia.org/resource/Abd_al-Kuri_sparrow'],
#  "abdim's stork": ["http://dbpedia.org/resource/Abdim's_stork"],
#  'aberdare cisticola': ['http://dbpedia.org/resource/Aberdare_cisticola'],
#  'aberrant bush warbler': ['http://dbpedia.org/resource/Aberrant_bush_warbler'],
#  ' cettia flavolivacea': ['http://dbpedia.org/resource/Aberrant_bush_warbler'],
#  ' cettia flavolivaceus': ['http://dbpedia.org/resource/Aberrant_bush_warbler'],
#  "abert's towhee": ["http://dbpedia.org/resource/Abert's_towhee"],
#  'pipilo aberti': ["http://dbpedia.org/resource/Abert's_towhee"],
#  'pyrgisoma aberti': ["http://dbpedia.org/resource/Abert's_towhee"],
#  'aboriginal cultural heritage act 2003': ['http://dbpedia.org/resource/Aboriginal_Cultural_Heritage_Act_2003'],
#  'aboriginal heritage act 1988': ['http://dbpedia.org/resource/Aboriginal_Heritage_Act_1988'],
#  'aboriginal and torres strait islander heritage protection act 1984': ['http://dbpedia.org/resource/Aboriginal_and_Torres_Strait_Islander_Heritage_Protection_Act_1984'],
#  'abortion law': ['http://dbpedia.org/resource/Abortion_law'],
#  'abyssinian catbird': ['http://dbpedia.org/resource/Abyssinian_catbird'],
#  'parophasma galinieri': ['http://dbpedia.org/resource/Abyssinian_catbird'],
#  'abyssinian ground thrush': ['http://dbpedia.org/resource/Abyssinian_ground_thrush'],
#  'zoothera piaggii (bouvier, 1977)': ['http://dbpedia.org/resource/Abyssinian_ground_thrush'],
#  'abyssinian longclaw': ['http://dbpedia.org/resource/Abyssinian_longclaw'],
#  'abyssinian owl': ['http://dbpedia.org/resource/Abyssinian_owl'],
#  'abyssinian scimitarbill': ['http://dbpedia.org/resource/Abyssinian_scimitarbill'],
#  'abyssinian slaty flycatcher': ['http://dbpedia.org/resource/Abyssinian_slaty_flycatcher'],
#  'muscicapa chocolatinus ': ['http://dbpedia.org/resource/Abyssinian_slaty_flycatcher'],
#  'dioptrornis chocolatinus (rüppell, 1840)': ['http://dbpedia.org/resource/Abyssinian_slaty_flycatcher'],
#  'abyssinian thrush': ['http://dbpedia.org/resource/Abyssinian_thrush'],
#  'turdus olivaceus abyssinicus': ['http://dbpedia.org/resource/Abyssinian_thrush'],
#  'abyssinian wheatear': ['http://dbpedia.org/resource/Abyssinian_wheatear'],
#  'abyssinian white-eye': ['http://dbpedia.org/resource/Abyssinian_white-eye'],
#  'abyssinian woodpecker': ['http://dbpedia.org/resource/Abyssinian_woodpecker'],
#  'picus abyssinicus ': ['http://dbpedia.org/resource/Abyssinian_woodpecker'],
#  'chloropicus abyssinicus': ['http://dbpedia.org/resource/Abyssinian_woodpecker'],
#  'acacia pied barbet': ['http://dbpedia.org/resource/Acacia_pied_barbet'],
#  'tricholaema affine': ['http://dbpedia.org/resource/Acacia_pied_barbet'],
#  'acacia tit': ['http://dbpedia.org/resource/Acacia_tit'],
#  'parus thruppi shelley, 1885': ['http://dbpedia.org/resource/Acacia_tit'],
#  'acadian flycatcher': ['http://dbpedia.org/resource/Acadian_flycatcher'],
#  'acanthiza': ['http://dbpedia.org/resource/Acanthiza'],
#  'accipiter': ['http://dbpedia.org/resource/Accipiter'],
#  'hieraspiza (kaup, 1844 )': ['http://dbpedia.org/resource/Accipiter'],
#  'aceros': ['http://dbpedia.org/resource/Aceros'],
#  'acorn woodpecker': ['http://dbpedia.org/resource/Acorn_woodpecker'],
#  'acquis communautaire': ['http://dbpedia.org/resource/Acquis_communautaire'],
#  'acre tody-tyrant': ['http://dbpedia.org/resource/Acre_tody-tyrant'],
#  'acridotheres': ['http://dbpedia.org/resource/Acridotheres'],
#  'acrocephalus (bird)': ['http://dbpedia.org/resource/Acrocephalus_(bird)'],
#  'act for the additional representation of barons': ['http://dbpedia.org/resource/Act_for_the_additional_representation_of_barons'],
#  'act of consolidation, 1854': ['http://dbpedia.org/resource/Act_of_Consolidation,_1854'],
#  'act of the national assembly for wales': ['http://dbpedia.org/resource/Act_of_the_National_Assembly_for_Wales'],
#  'actenoides': ['http://dbpedia.org/resource/Actenoides'],
#  'acts of supremacy': ['http://dbpedia.org/resource/Acts_of_Supremacy'],
#  'adamawa turtle dove': ['http://dbpedia.org/resource/Adamawa_turtle_dove'],
#  'adar llwch gwin': ['http://dbpedia.org/resource/Adar_Llwch_Gwin'],
#  "adelaide's warbler": ["http://dbpedia.org/resource/Adelaide's_warbler"],
#  'dendroica adelaidae (baird, 1865)': ["http://dbpedia.org/resource/Adelaide's_warbler"],
#  "administrative procedure law of the people's republic of china": ["http://dbpedia.org/resource/Administrative_Procedure_Law_of_the_People's_Republic_of_China"],
#  'adélie penguin': ['http://dbpedia.org/resource/Adélie_penguin'],
#  'aechmophorus': ['http://dbpedia.org/resource/Aechmophorus'],
#  'aegithalos': ['http://dbpedia.org/resource/Aegithalos'],
#  'orites (g.r.gray, 1841 )': ['http://dbpedia.org/resource/Aegithalos'],
#  'aegolius': ['http://dbpedia.org/resource/Aegolius'],
#  'aepyornis': ['http://dbpedia.org/resource/Aepyornis'],
#  'aepypodius': ['http://dbpedia.org/resource/Aepypodius'],
#  'aerodramus': ['http://dbpedia.org/resource/Aerodramus'],
#  'aeronautes': ['http://dbpedia.org/resource/Aeronautes'],
#  'aethopyga': ['http://dbpedia.org/resource/Aethopyga'],
#  'afghan babbler': ['http://dbpedia.org/resource/Afghan_babbler'],
#  'turdoides huttoni': ['http://dbpedia.org/resource/Afghan_babbler'],
#  'afghan snowfinch': ['http://dbpedia.org/resource/Afghan_snowfinch'],
#  ' montifringilla theresae (r. meinzertzhagen, 1937)': ['http://dbpedia.org/resource/Afghan_snowfinch'],
#  'african growth and opportunity act': ['http://dbpedia.org/resource/African_Growth_and_Opportunity_Act'],
#  'african barred owlet': ['http://dbpedia.org/resource/African_barred_owlet'],
#  'african black duck': ['http://dbpedia.org/resource/African_black_duck'],
#  'african black swift': ['http://dbpedia.org/resource/African_black_swift'],
#  'african blue flycatcher': ['http://dbpedia.org/resource/African_blue_flycatcher'],
#  'myiagra longicauda': ['http://dbpedia.org/resource/African_blue_flycatcher'],
#  'african blue tit': ['http://dbpedia.org/resource/African_blue_tit'],
#  'parus teneriffae (lesson, 1831)': ['http://dbpedia.org/resource/African_blue_tit'],
#  'african broadbill': ['http://dbpedia.org/resource/African_broadbill'],
#  'platyrhynchus capensis( a. smith, 1839)': ['http://dbpedia.org/resource/African_broadbill'],
#  'african citril': ['http://dbpedia.org/resource/African_citril'],
#  'serinus citrinelloides': ['http://dbpedia.org/resource/African_citril'],
#  'african crake': ['http://dbpedia.org/resource/African_crake'],
#  'crex egregia': ['http://dbpedia.org/resource/African_crake'],
#  'ortygometra egregia': ['http://dbpedia.org/resource/African_crake'],
#  'porzana egregia': ['http://dbpedia.org/resource/African_crake'],
#  'african crimson-winged finch': ['http://dbpedia.org/resource/African_crimson-winged_finch'],
#  'african cuckoo': ['http://dbpedia.org/resource/African_cuckoo'],
#  'african cuckoo-hawk': ['http://dbpedia.org/resource/African_cuckoo-hawk'],
#  'african darter': ['http://dbpedia.org/resource/African_darter'],
#  'anhinga africana': ['http://dbpedia.org/resource/African_darter'],
#  'african desert warbler': ['http://dbpedia.org/resource/African_desert_warbler'],
#  "''stoparola deserti'": ['http://dbpedia.org/resource/African_desert_warbler'],
#  'african dusky flycatcher': ['http://dbpedia.org/resource/African_dusky_flycatcher'],
#  'african dwarf kingfisher': ['http://dbpedia.org/resource/African_dwarf_kingfisher'],
#  'ceyx lecontei': ['http://dbpedia.org/resource/African_dwarf_kingfisher'],
#  'african emerald cuckoo': ['http://dbpedia.org/resource/African_emerald_cuckoo'],
#  'african finfoot': ['http://dbpedia.org/resource/African_finfoot'],
#  'heliornis senegalensis (viellot, 1817)': ['http://dbpedia.org/resource/African_finfoot'],
#  'african goshawk': ['http://dbpedia.org/resource/African_goshawk'],
#  'falco tachiro (daudin, 1800)': ['http://dbpedia.org/resource/African_goshawk'],
#  'african grass owl': ['http://dbpedia.org/resource/African_grass_owl'],
#  'african green pigeon': ['http://dbpedia.org/resource/African_green_pigeon'],
#  'african grey flycatcher': ['http://dbpedia.org/resource/African_grey_flycatcher'],
#  'bradornis microrhynchus': ['http://dbpedia.org/resource/African_grey_flycatcher'],
#  'african grey parrot': ['http://dbpedia.org/resource/African_grey_parrot'],
#  'african harrier-hawk': ['http://dbpedia.org/resource/African_harrier-hawk'],
#  'african hawk-eagle': ['http://dbpedia.org/resource/African_hawk-eagle'],
#  'hieraaetus spilogaster': ['http://dbpedia.org/resource/African_hawk-eagle'],
#  'african hill babbler': ['http://dbpedia.org/resource/African_hill_babbler'],
#  'alcippe abyssinica': ['http://dbpedia.org/resource/African_hill_babbler'],
#  'illadopsis abyssinica': ['http://dbpedia.org/resource/African_hill_babbler'],
#  'illadopsis stierlingi': ['http://dbpedia.org/resource/African_hill_babbler'],
#  'pseudoalcippe abyssinica': ['http://dbpedia.org/resource/African_hill_babbler'],
#  'african jacana': ['http://dbpedia.org/resource/African_jacana'],
#  'african marsh harrier': ['http://dbpedia.org/resource/African_marsh_harrier'],
#  'african olive pigeon': ['http://dbpedia.org/resource/African_olive_pigeon'],
#  'african openbill': ['http://dbpedia.org/resource/African_openbill'],
#  'african palm swift': ['http://dbpedia.org/resource/African_palm_swift'],
#  'african paradise flycatcher': ['http://dbpedia.org/resource/African_paradise_flycatcher'],
#  ' muscicapa viridis': ['http://dbpedia.org/resource/African_paradise_flycatcher'],
#  ' terpsiphone granti': ['http://dbpedia.org/resource/African_paradise_flycatcher'],
#  ' terpsiphone perspicillata': ['http://dbpedia.org/resource/African_paradise_flycatcher'],
#  ' terpsiphone poliothorax': ['http://dbpedia.org/resource/African_paradise_flycatcher'],
#  ' terpsiphone suahelica': ['http://dbpedia.org/resource/African_paradise_flycatcher'],
#  'african penguin': ['http://dbpedia.org/resource/African_penguin'],
#  'diomedea demersa': ['http://dbpedia.org/resource/African_penguin'],
#  'african piculet': ['http://dbpedia.org/resource/African_piculet'],
#  ' verreauxia africana': ['http://dbpedia.org/resource/African_piculet'],
#  'african pied hornbill': ['http://dbpedia.org/resource/African_pied_hornbill'],
#  'tockus fasciatus': ['http://dbpedia.org/resource/African_pied_hornbill'],
#  'african pied wagtail': ['http://dbpedia.org/resource/African_pied_wagtail'],
#  'african pitta': ['http://dbpedia.org/resource/African_pitta'],
#  'african pygmy goose': ['http://dbpedia.org/resource/African_pygmy_goose'],
#  'african pygmy kingfisher': ['http://dbpedia.org/resource/African_pygmy_kingfisher'],
#  'ceyx pictus': ['http://dbpedia.org/resource/African_pygmy_kingfisher'],
#  'african rail': ['http://dbpedia.org/resource/African_rail'],
#  'african red-eyed bulbul': ['http://dbpedia.org/resource/African_red-eyed_bulbul'],
#  ' turdus nigricans': ['http://dbpedia.org/resource/African_red-eyed_bulbul'],
#  'african reed warbler': ['http://dbpedia.org/resource/African_reed_warbler'],
#  'african river martin': ['http://dbpedia.org/resource/African_river_martin'],
#  'african rock pipit': ['http://dbpedia.org/resource/African_rock_pipit'],
#  'african sacred ibis': ['http://dbpedia.org/resource/African_sacred_ibis'],
#  'tantalus aethiopicus (latham, 1790)': ['http://dbpedia.org/resource/African_sacred_ibis'],
#  'african scops owl': ['http://dbpedia.org/resource/African_scops_owl'],
#  'african shrike-flycatcher': ['http://dbpedia.org/resource/African_shrike-flycatcher'],
#  'bias flammulatus': ['http://dbpedia.org/resource/African_shrike-flycatcher'],
#  'african silverbill': ['http://dbpedia.org/resource/African_silverbill'],
#  'lonchura cantans': ['http://dbpedia.org/resource/African_silverbill'],
#  'african snipe': ['http://dbpedia.org/resource/African_snipe'],
#  'african spoonbill': ['http://dbpedia.org/resource/African_spoonbill'],
#  'platalea tenuirostris (temminck, 1820)': ['http://dbpedia.org/resource/African_spoonbill'],
#  'african spotted creeper': ['http://dbpedia.org/resource/African_spotted_creeper'],
#  'african swamphen': ['http://dbpedia.org/resource/African_swamphen'],
#  'porphyrio porphyrio madagascariensis': ['http://dbpedia.org/resource/African_swamphen'],
#  'african thrush': ['http://dbpedia.org/resource/African_thrush'],
#  'african wood owl': ['http://dbpedia.org/resource/African_wood_owl'],
#  'ciccaba woodfordii ( smith a., 1834)': ['http://dbpedia.org/resource/African_wood_owl'],
#  'african yellow warbler': ['http://dbpedia.org/resource/African_yellow_warbler'],
#  'chloropeta natalensis': ['http://dbpedia.org/resource/African_yellow_warbler'],
#  'african yellow white-eye': ['http://dbpedia.org/resource/African_yellow_white-eye'],
#  'afrotis': ['http://dbpedia.org/resource/Afrotis'],
#  'agami heron': ['http://dbpedia.org/resource/Agami_heron'],
#  'agelaius': ['http://dbpedia.org/resource/Agelaius'],
#  'agelasticus': ['http://dbpedia.org/resource/Agelasticus'],
#  'agile tit-tyrant': ['http://dbpedia.org/resource/Agile_tit-tyrant'],
#  'anairetes agilis': ['http://dbpedia.org/resource/Agile_tit-tyrant'],
#  'aglaeactis': ['http://dbpedia.org/resource/Aglaeactis'],
#  'aglaiocercus': ['http://dbpedia.org/resource/Aglaiocercus'],
#  'agricultural research, extension, and education reform act of 1998': ['http://dbpedia.org/resource/Agricultural_Research,_Extension,_and_Education_Reform_Act_of_1998'],
#  'agriculture and fisheries modernization act of 1997': ['http://dbpedia.org/resource/Agriculture_and_Fisheries_Modernization_Act_of_1997'],
#  'agropsar': ['http://dbpedia.org/resource/Agropsar'],
#  'aguiguan reed warbler': ['http://dbpedia.org/resource/Aguiguan_reed_warbler'],
#  'agulhas long-billed lark': ['http://dbpedia.org/resource/Agulhas_long-billed_lark'],
#  ' certhilauda curvirostris brevirostris': ['http://dbpedia.org/resource/Agulhas_long-billed_lark'],
#  'ahanta francolin': ['http://dbpedia.org/resource/Ahanta_francolin'],
#  'ailuroedus': ['http://dbpedia.org/resource/Ailuroedus'],
#  'aimophila': ['http://dbpedia.org/resource/Aimophila'],
#  'aiolornis': ['http://dbpedia.org/resource/Aiolornis'],
#  'aiornis': ['http://dbpedia.org/resource/Aiolornis'],
#  'teratornis incredibilis (howard, 1952)': ['http://dbpedia.org/resource/Aiolornis'],
#  'akalat': ['http://dbpedia.org/resource/Akalat'],
#  'akun eagle-owl': ['http://dbpedia.org/resource/Akun_eagle-owl'],
#  'alaemon': ['http://dbpedia.org/resource/Alaemon'],
#  'alagoas antwren': ['http://dbpedia.org/resource/Alagoas_antwren'],
#  'alagoas curassow': ['http://dbpedia.org/resource/Alagoas_curassow'],
#  ' mitu mitu mitu ': ['http://dbpedia.org/resource/Alagoas_curassow'],
#  ' crax mitu': ['http://dbpedia.org/resource/Alagoas_curassow'],
#  'alagoas foliage-gleaner': ['http://dbpedia.org/resource/Alagoas_foliage-gleaner'],
#  'alagoas tyrannulet': ['http://dbpedia.org/resource/Alagoas_tyrannulet'],
#  'alaotra grebe': ['http://dbpedia.org/resource/Alaotra_grebe'],
#  'alauda': ['http://dbpedia.org/resource/Alauda'],
#  'albatross': ['http://dbpedia.org/resource/Albatross'],
#  'albertine owlet': ['http://dbpedia.org/resource/Albertine_owlet'],
#  'alcedo': ['http://dbpedia.org/resource/Alcedo'],
#  'alcippe (bird)': ['http://dbpedia.org/resource/Alcippe_(bird)'],
#  'aldabra brush warbler': ['http://dbpedia.org/resource/Aldabra_brush_warbler'],
#  'nesillas aldabranus': ['http://dbpedia.org/resource/Aldabra_brush_warbler'],
#  'aldabra drongo': ['http://dbpedia.org/resource/Aldabra_drongo'],
#  'alder flycatcher': ['http://dbpedia.org/resource/Alder_flycatcher'],
#  'alectrurus': ['http://dbpedia.org/resource/Alectrurus'],
#  ' alectorurus gloger, 1842': ['http://dbpedia.org/resource/Alectrurus'],
#  ' alectrura reichenbach, 1850': ['http://dbpedia.org/resource/Alectrurus'],
#  ' alectrururus giebel, 1872': ['http://dbpedia.org/resource/Alectrurus'],
#  ' alectura swainson, 1837': ['http://dbpedia.org/resource/Alectrurus'],
#  ' alecturus temminck, 1822': ['http://dbpedia.org/resource/Alectrurus'],
#  'aleutian tern': ['http://dbpedia.org/resource/Aleutian_tern'],
#  'sterna aleutica (baird, 1869)': ['http://dbpedia.org/resource/Aleutian_tern'],
#  'alex (parrot)': ['http://dbpedia.org/resource/Alex_(parrot)'],
#  'alexornis': ['http://dbpedia.org/resource/Alexornis'],
#  'algerian nuthatch': ['http://dbpedia.org/resource/Algerian_nuthatch'],
#  'alicanto': ['http://dbpedia.org/resource/Alicanto'],
#  'all alone (pigeon)': ['http://dbpedia.org/resource/All_Alone_(pigeon)'],
#  "allen's gallinule": ["http://dbpedia.org/resource/Allen's_gallinule"],
#  "allen's hummingbird": ["http://dbpedia.org/resource/Allen's_hummingbird"],
#  'allpahuayo antbird': ['http://dbpedia.org/resource/Allpahuayo_antbird'],
#  'alophoixus': ['http://dbpedia.org/resource/Alophoixus'],
#  'alpine accentor': ['http://dbpedia.org/resource/Alpine_accentor'],
#  'laiscopus collaris': ['http://dbpedia.org/resource/Alpine_accentor'],
#  'alpine chough': ['http://dbpedia.org/resource/Alpine_chough'],
#  'corvus graculus': ['http://dbpedia.org/resource/Alpine_chough'],
#  'alpine leaf warbler': ['http://dbpedia.org/resource/Alpine_leaf_warbler'],
#  'alpine pipit': ['http://dbpedia.org/resource/Alpine_pipit'],
#  'alpine swift': ['http://dbpedia.org/resource/Alpine_swift'],
#  'hirundo melba ': ['http://dbpedia.org/resource/Alpine_swift'],
#  'apus melba': ['http://dbpedia.org/resource/Alpine_swift'],
#  "alström's warbler": ["http://dbpedia.org/resource/Alström's_warbler"],
#  'seicercus soror': ["http://dbpedia.org/resource/Alström's_warbler"],
#  'alta floresta antpitta': ['http://dbpedia.org/resource/Alta_Floresta_antpitta'],
#  'altai accentor': ['http://dbpedia.org/resource/Altai_accentor'],
#  'laiscopus himalayanus': ['http://dbpedia.org/resource/Altai_accentor'],
#  'altai falcon': ['http://dbpedia.org/resource/Altai_falcon'],
#  'falco altaicus': ['http://dbpedia.org/resource/Altai_falcon'],
#  'hierofalco altaicus (menzbier, 1891)': ['http://dbpedia.org/resource/Altai_falcon'],
#  'falco lorenzi (sushkin, 1938)': ['http://dbpedia.org/resource/Altai_falcon'],
#  'altai snowcock': ['http://dbpedia.org/resource/Altai_snowcock'],
#  'perdix altaica( gebler,1836)': ['http://dbpedia.org/resource/Altai_snowcock'],
#  'altamira oriole': ['http://dbpedia.org/resource/Altamira_oriole'],
#  'altamira yellowthroat': ['http://dbpedia.org/resource/Altamira_yellowthroat'],
#  'amadina': ['http://dbpedia.org/resource/Amadina'],
#  'amalocichla': ['http://dbpedia.org/resource/Amalocichla'],
#  'amami woodcock': ['http://dbpedia.org/resource/Amami_woodcock'],
#  'amami woodpecker': ['http://dbpedia.org/resource/Amami_woodpecker'],
#  'amani sunbird': ['http://dbpedia.org/resource/Amani_sunbird'],
#  'anthodiaeta pallidigaster': ['http://dbpedia.org/resource/Amani_sunbird'],
#  'anthreptes pallidigaster': ['http://dbpedia.org/resource/Amani_sunbird'],
#  'amaurornis': ['http://dbpedia.org/resource/Amaurornis'],
#  'poliolimnas (sharpe, 1893)': ['http://dbpedia.org/resource/Amaurornis'],
#  'amaurospiza': ['http://dbpedia.org/resource/Amaurospiza'],
#  'amazilia': ['http://dbpedia.org/resource/Amazilia'],
#  'amazilia hummingbird': ['http://dbpedia.org/resource/Amazilia_hummingbird'],
#  'amazonian antpitta': ['http://dbpedia.org/resource/Amazonian_antpitta'],
#  'amazonian antshrike': ['http://dbpedia.org/resource/Amazonian_antshrike'],
#  'amazonian barred woodcreeper': ['http://dbpedia.org/resource/Amazonian_barred_woodcreeper'],
#  'amazonian black tyrant': ['http://dbpedia.org/resource/Amazonian_black_tyrant'],
#  'amazonian black-breasted woodpecker': ['http://dbpedia.org/resource/Amazonian_black-breasted_woodpecker'],
#  'amazonian inezia': ['http://dbpedia.org/resource/Amazonian_inezia'],
#  'amazonian pygmy owl': ['http://dbpedia.org/resource/Amazonian_pygmy_owl'],
#  'amazonian royal flycatcher': ['http://dbpedia.org/resource/Amazonian_royal_flycatcher'],
#  'amazonian scrub flycatcher': ['http://dbpedia.org/resource/Amazonian_scrub_flycatcher'],
#  'amazonian streaked antwren': ['http://dbpedia.org/resource/Amazonian_streaked_antwren'],
#  'amazonian umbrellabird': ['http://dbpedia.org/resource/Amazonian_umbrellabird'],
#  'amber mountain rock thrush': ['http://dbpedia.org/resource/Amber_Mountain_rock_thrush'],
#  'pseudocossyphus erythronotus': ['http://dbpedia.org/resource/Amber_Mountain_rock_thrush'],
#  'amblyornis': ['http://dbpedia.org/resource/Amblyornis'],
#  'ambon white-eye': ['http://dbpedia.org/resource/Ambon_white-eye'],
#  'american avocet': ['http://dbpedia.org/resource/American_avocet'],
#  'american bittern': ['http://dbpedia.org/resource/American_bittern'],
#  'palaeophoyx columbiana (mccoy, 1963)': ['http://dbpedia.org/resource/American_bittern'],
#  'american black duck': ['http://dbpedia.org/resource/American_black_duck'],
#  'anas obscura (gmelin, 1789)': ['http://dbpedia.org/resource/American_black_duck'],
#  'american coot': ['http://dbpedia.org/resource/American_coot'],
#  'and see text': ['http://dbpedia.org/resource/Vanellus'],
#  ' fulica hesterna (howard, 1963)': ['http://dbpedia.org/resource/American_coot'],
#  'american dipper': ['http://dbpedia.org/resource/American_dipper'],
#  'american dusky flycatcher': ['http://dbpedia.org/resource/American_dusky_flycatcher'],
#  'american golden plover': ['http://dbpedia.org/resource/American_golden_plover'],
#  'pluvialis dominica dominica': ['http://dbpedia.org/resource/American_golden_plover'],
#  'american goldfinch': ['http://dbpedia.org/resource/American_goldfinch'],
#  ' fringilla tristis ': ['http://dbpedia.org/resource/American_goldfinch'],
#  ' astragalinus tristis ': ['http://dbpedia.org/resource/American_goldfinch'],
#  ' carduelis tristis': ['http://dbpedia.org/resource/American_goldfinch'],
#  'american gray flycatcher': ['http://dbpedia.org/resource/American_gray_flycatcher'],
#  'american green kingfisher': ['http://dbpedia.org/resource/American_green_kingfisher'],
#  'american herring gull': ['http://dbpedia.org/resource/American_herring_gull'],
#  'larus argentatus smithsonianus': ['http://dbpedia.org/resource/American_herring_gull'],
#  'american kestrel': ['http://dbpedia.org/resource/American_kestrel'],
#  'american redstart': ['http://dbpedia.org/resource/American_redstart'],
#  'motacilla ruticilla ': ['http://dbpedia.org/resource/American_redstart'],
#  'muscicapa ruticilla': ['http://dbpedia.org/resource/American_redstart'],
#  'american robin': ['http://dbpedia.org/resource/American_robin'],
#  'merula migratoria': ['http://dbpedia.org/resource/American_robin'],
#  'planesticus migratorius': ['http://dbpedia.org/resource/American_robin'],
#  'american three-toed woodpecker': ['http://dbpedia.org/resource/American_three-toed_woodpecker'],
#  'american tree sparrow': ['http://dbpedia.org/resource/American_tree_sparrow'],
#  'passerella arborea': ['http://dbpedia.org/resource/American_tree_sparrow'],
#  'spizella arborea': ['http://dbpedia.org/resource/American_tree_sparrow'],
#  'spizella monticola': ['http://dbpedia.org/resource/American_tree_sparrow'],
#  'american white ibis': ['http://dbpedia.org/resource/American_white_ibis'],
#  'scolopax alba ': ['http://dbpedia.org/resource/American_white_ibis'],
#  'scolopax fusca ': ['http://dbpedia.org/resource/American_white_ibis'],
#  'tantalus albus ': ['http://dbpedia.org/resource/American_white_ibis'],
#  'tantalus fuscus': ['http://dbpedia.org/resource/American_white_ibis'],
#  'american white pelican': ['http://dbpedia.org/resource/American_white_pelican'],
#  'pelecanus erythrorhynchus': ['http://dbpedia.org/resource/American_white_pelican'],
#  'american wigeon': ['http://dbpedia.org/resource/American_wigeon'],
#  'anas americana (gmelin, 1789)': ['http://dbpedia.org/resource/American_wigeon'],
#  'amethyst brown dove': ['http://dbpedia.org/resource/Amethyst_brown_dove'],
#  'amethyst sunbird': ['http://dbpedia.org/resource/Amethyst_sunbird'],
#  'nectarinia amethystina': ['http://dbpedia.org/resource/Amethyst_sunbird'],
#  'amethyst woodstar': ['http://dbpedia.org/resource/Amethyst_woodstar'],
#  'amethyst-throated mountaingem': ['http://dbpedia.org/resource/Amethyst-throated_mountaingem'],
#  'amethyst-throated sunangel': ['http://dbpedia.org/resource/Amethyst-throated_sunangel'],
#  'heliangelus laticlavius': ['http://dbpedia.org/resource/Amethyst-throated_sunangel'],
#  'amihan (mythology)': ['http://dbpedia.org/resource/Amihan_(mythology)'],
#  'amitabha (bird)': ['http://dbpedia.org/resource/Amitabha_(bird)'],
#  'ammomanes': ['http://dbpedia.org/resource/Ammomanes'],
#  'ampelion': ['http://dbpedia.org/resource/Ampelion'],
#  'amphispiza': ['http://dbpedia.org/resource/Amphispiza'],
#  'amsterdam albatross': ['http://dbpedia.org/resource/Amsterdam_albatross'],
#  'diomedea exulans amsterdamensis': ['http://dbpedia.org/resource/Amsterdam_albatross'],
#  '(roux, jouventin, mougin, stahl & weimerskirch 1983)': ['http://dbpedia.org/resource/Amsterdam_albatross'],
#  'amsterdam wigeon': ['http://dbpedia.org/resource/Amsterdam_wigeon'],
#  'anas marecula': ['http://dbpedia.org/resource/Amsterdam_wigeon'],
#  'amur falcon': ['http://dbpedia.org/resource/Amur_falcon'],
#  ' erythropus amurensis': ['http://dbpedia.org/resource/Amur_falcon'],
#  ' falco vespertinus var. amurensis': ['http://dbpedia.org/resource/Amur_falcon'],
#  'amur paradise flycatcher': ['http://dbpedia.org/resource/Amur_paradise_flycatcher'],
#  ' muscipeta incei': ['http://dbpedia.org/resource/Amur_paradise_flycatcher'],
#  ' terpsiphone paradisi incei': ['http://dbpedia.org/resource/Amur_paradise_flycatcher'],
#  'amytornis': ['http://dbpedia.org/resource/Amytornis'],
#  'anabacerthia': ['http://dbpedia.org/resource/Anabacerthia'],
#  'anabathmis': ['http://dbpedia.org/resource/Anabathmis'],
#  'anabazenops': ['http://dbpedia.org/resource/Anabazenops'],
#  'anambra waxbill': ['http://dbpedia.org/resource/Anambra_waxbill'],
#  'anas': ['http://dbpedia.org/resource/Anas'],
#  ' querquedula': ['http://dbpedia.org/resource/Anas'],
#  ' punanetta': ['http://dbpedia.org/resource/Anas'],
#  'anatalavis': ['http://dbpedia.org/resource/Anatalavis'],
#  ' nettapterornis (mlikovsky, 2002)': ['http://dbpedia.org/resource/Anatalavis'],
#  'ancash tapaculo': ['http://dbpedia.org/resource/Ancash_tapaculo'],
#  "anchieta's barbet": ["http://dbpedia.org/resource/Anchieta's_barbet"],
#  "anchieta's sunbird": ["http://dbpedia.org/resource/Anchieta's_sunbird"],
#  'ancient antwren': ['http://dbpedia.org/resource/Ancient_antwren'],
#  'ancient murrelet': ['http://dbpedia.org/resource/Ancient_murrelet'],
#  'andalgalornis': ['http://dbpedia.org/resource/Andalgalornis'],
#  ' phororhacos steulleti': ['http://dbpedia.org/resource/Andalgalornis'],
#  '(kraglievich, 1931)': ['http://dbpedia.org/resource/Andalgalornis'],
#  ' phororhacos deautieri': ['http://dbpedia.org/resource/Andalgalornis'],
#  ' andalgalornis ferox': ['http://dbpedia.org/resource/Andalgalornis'],
#  '(patterson & kraglievich, 1960)': ['http://dbpedia.org/resource/Andalgalornis'],
#  ' phorohacos deautieri': ['http://dbpedia.org/resource/Andalgalornis'],
#  'andaman coucal': ['http://dbpedia.org/resource/Andaman_coucal'],
#  'centropus sinensis andamanensis': ['http://dbpedia.org/resource/Andaman_coucal'],
#  'andaman cuckoo-dove': ['http://dbpedia.org/resource/Andaman_cuckoo-dove'],
#  'andaman cuckooshrike': ['http://dbpedia.org/resource/Andaman_cuckooshrike'],
#  'andaman drongo': ['http://dbpedia.org/resource/Andaman_drongo'],
#  'andaman flowerpecker': ['http://dbpedia.org/resource/Andaman_flowerpecker'],
#  'andaman green pigeon': ['http://dbpedia.org/resource/Andaman_green_pigeon'],
#  'andaman hawk-owl': ['http://dbpedia.org/resource/Andaman_hawk-owl'],
#  'andaman masked owl': ['http://dbpedia.org/resource/Andaman_masked_owl'],
#  'andaman nightjar': ['http://dbpedia.org/resource/Andaman_nightjar'],
#  'andaman scops owl': ['http://dbpedia.org/resource/Andaman_scops_owl'],
#  'andaman serpent eagle': ['http://dbpedia.org/resource/Andaman_serpent_eagle'],
#  'andaman shama': ['http://dbpedia.org/resource/Andaman_shama'],
#  'andaman teal': ['http://dbpedia.org/resource/Andaman_teal'],
#  'mareca albogularis (hume, 1873)': ['http://dbpedia.org/resource/Andaman_teal'],
#  'nettion albigulare': ['http://dbpedia.org/resource/Andaman_teal'],
#  'nettium albigulare': ['http://dbpedia.org/resource/Andaman_teal'],
#  'andaman treepie': ['http://dbpedia.org/resource/Andaman_treepie'],
#  ' dendrocitta bayleyi': ['http://dbpedia.org/resource/Andaman_treepie'],
#  'andaman wood pigeon': ['http://dbpedia.org/resource/Andaman_wood_pigeon'],
#  'andaman woodpecker': ['http://dbpedia.org/resource/Andaman_woodpecker'],
#  'andean avocet': ['http://dbpedia.org/resource/Andean_avocet'],
#  'andean blossomcrown': ['http://dbpedia.org/resource/Andean_blossomcrown'],
#  'andean cock-of-the-rock': ['http://dbpedia.org/resource/Andean_cock-of-the-rock'],
#  'andean condor': ['http://dbpedia.org/resource/Andean_condor'],
#  ' vultur fossilis (moreno & mercerat, 1891)': ['http://dbpedia.org/resource/Andean_condor'],
#  ' vultur patruus (lönnberg, 1902)': ['http://dbpedia.org/resource/Andean_condor'],
#  ' vultur pratruus (emslie, 1988 )': ['http://dbpedia.org/resource/Andean_condor'],
#  'andean coot': ['http://dbpedia.org/resource/Andean_coot'],
#  'andean emerald': ['http://dbpedia.org/resource/Andean_emerald'],
#  'andean flamingo': ['http://dbpedia.org/resource/Andean_flamingo'],
#  'phoenicopterus andinus ssp. andinus (philippi, 1854)': ['http://dbpedia.org/resource/Andean_flamingo'],
#  'andean gull': ['http://dbpedia.org/resource/Andean_gull'],
#  'larus serranus': ['http://dbpedia.org/resource/Andean_gull'],
#  'andean hillstar': ['http://dbpedia.org/resource/Andean_hillstar'],
#  'andean lapwing': ['http://dbpedia.org/resource/Andean_lapwing'],
#  'belonopterus resplendens': ['http://dbpedia.org/resource/Andean_lapwing'],
#  'charadrius resplendens (tschudi, 1843)': ['http://dbpedia.org/resource/Andean_lapwing'],
#  'ptiloscelys resplendens': ['http://dbpedia.org/resource/Andean_lapwing'],
#  'andean negrito': ['http://dbpedia.org/resource/Andean_negrito'],
#  'centrites oreas': ['http://dbpedia.org/resource/Andean_negrito'],
#  'andean parakeet': ['http://dbpedia.org/resource/Andean_parakeet'],
#  'bolborhynchus andicola': ['http://dbpedia.org/resource/Andean_parakeet'],
#  'andean potoo': ['http://dbpedia.org/resource/Andean_potoo'],
#  'andean pygmy owl': ['http://dbpedia.org/resource/Andean_pygmy_owl'],
#  'andean siskin': ['http://dbpedia.org/resource/Andean_siskin'],
#  'carduelis spinescens': ['http://dbpedia.org/resource/Andean_siskin'],
#  'sporagra spinescens': ['http://dbpedia.org/resource/Andean_siskin'],
#  'andean slaty thrush': ['http://dbpedia.org/resource/Andean_slaty_thrush'],
#  'andean solitaire': ['http://dbpedia.org/resource/Andean_solitaire'],
#  'andean swallow': ['http://dbpedia.org/resource/Andean_swallow'],
#  'petrochelidon andecola': ['http://dbpedia.org/resource/Andean_swallow'],
#  'andean tapaculo': ['http://dbpedia.org/resource/Andean_tapaculo'],
#  'andean tinamou': ['http://dbpedia.org/resource/Andean_tinamou'],
#  'andean tit-spinetail': ['http://dbpedia.org/resource/Andean_tit-spinetail'],
#  'angolan batis': ['http://dbpedia.org/resource/Angolan_batis'],
#  'angolan cave chat': ['http://dbpedia.org/resource/Angolan_cave_chat'],
#  'xenocopsychus ansorgei': ['http://dbpedia.org/resource/Angolan_cave_chat'],
#  'angolan lark': ['http://dbpedia.org/resource/Angolan_lark'],
#  'angolan slaty flycatcher': ['http://dbpedia.org/resource/Angolan_slaty_flycatcher'],
#  'dioptrornis brunneus': ['http://dbpedia.org/resource/Angolan_slaty_flycatcher'],
#  'angolan swallow': ['http://dbpedia.org/resource/Angolan_swallow'],
#  'anhinga': ['http://dbpedia.org/resource/Anhinga'],
#  'plotus anhinga': ['http://dbpedia.org/resource/Anhinga'],
#  'anisognathus': ['http://dbpedia.org/resource/Anisognathus'],
#  'anjouan brush warbler': ['http://dbpedia.org/resource/Anjouan_brush_warbler'],
#  'anjouan scops owl': ['http://dbpedia.org/resource/Anjouan_scops_owl'],
#  'anjouan sunbird': ['http://dbpedia.org/resource/Anjouan_sunbird'],
#  'ankober serin': ['http://dbpedia.org/resource/Ankober_serin'],
#  'serinus ankoberensis': ['http://dbpedia.org/resource/Ankober_serin'],
#  "anna's hummingbird": ["http://dbpedia.org/resource/Anna's_hummingbird"],
#  'annobón paradise flycatcher': ['http://dbpedia.org/resource/Annobón_paradise_flycatcher'],
#  ' muscipeta smithii': ['http://dbpedia.org/resource/Annobón_paradise_flycatcher'],
#  ' terpsiphone newtoni': ['http://dbpedia.org/resource/Annobón_paradise_flycatcher'],
#  ' terpsiphone rufiventer smithii': ['http://dbpedia.org/resource/Annobón_paradise_flycatcher'],
#  'annobón white-eye': ['http://dbpedia.org/resource/Annobón_white-eye'],
#  'anodorhynchus': ['http://dbpedia.org/resource/Anodorhynchus'],
#  'anorrhinus': ['http://dbpedia.org/resource/Anorrhinus'],
#  'ptilolaemus': ['http://dbpedia.org/resource/Anorrhinus'],
#  'anous': ['http://dbpedia.org/resource/Anous'],
#  'procelsterna lafresnaye, 1842': ['http://dbpedia.org/resource/Anous'],
#  "ansorge's greenbul": ["http://dbpedia.org/resource/Ansorge's_greenbul"],
#  ' andropadus ansorgei': ["http://dbpedia.org/resource/Ansorge's_greenbul"],
#  ' andropadus gracilis ansorgei': ["http://dbpedia.org/resource/Ansorge's_greenbul"],
#  ' pycnonotus ansorgei': ["http://dbpedia.org/resource/Ansorge's_greenbul"],
#  'ant follower': ['http://dbpedia.org/resource/Ant_follower'],
#  'ant-eating chat': ['http://dbpedia.org/resource/Ant-eating_chat'],
#  'antarctic tern': ['http://dbpedia.org/resource/Antarctic_tern'],
#  'anteater chat': ['http://dbpedia.org/resource/Anteater_chat'],
#  'anthipes': ['http://dbpedia.org/resource/Anthipes'],
#  "anthony's nightjar": ["http://dbpedia.org/resource/Anthony's_nightjar"],
#  'caprimulgus anthonyi': ["http://dbpedia.org/resource/Anthony's_nightjar"],
#  'anthoscopus': ['http://dbpedia.org/resource/Anthoscopus'],
#  'anthracoceros': ['http://dbpedia.org/resource/Anthracoceros'],
#  'anthracothorax': ['http://dbpedia.org/resource/Anthracothorax'],
#  'anthreptes': ['http://dbpedia.org/resource/Anthreptes'],
#  'anthropornis': ['http://dbpedia.org/resource/Anthropornis'],
#  'anti-terrorism act 2005': ['http://dbpedia.org/resource/Anti-Terrorism_Act_2005'],
#  'anti-urinal law': ['http://dbpedia.org/resource/Anti-Urinal_Law'],
#  'anti-bullying legislation': ['http://dbpedia.org/resource/Anti-bullying_legislation'],
#  'anti-literacy law': ['http://dbpedia.org/resource/Anti-literacy_law'],
#  'antillean crested hummingbird': ['http://dbpedia.org/resource/Antillean_crested_hummingbird'],
#  'trochilus cristatus': ['http://dbpedia.org/resource/Antillean_crested_hummingbird'],
#  'antillean mango': ['http://dbpedia.org/resource/Antillean_mango'],
#  'trochilus dominicus': ['http://dbpedia.org/resource/Antillean_mango'],
#  'antillean nighthawk': ['http://dbpedia.org/resource/Antillean_nighthawk'],
#  'antillean palm swift': ['http://dbpedia.org/resource/Antillean_palm_swift'],
#  'antillean piculet': ['http://dbpedia.org/resource/Antillean_piculet'],
#  'antillean siskin': ['http://dbpedia.org/resource/Antillean_siskin'],
#  'carduelis dominicensis': ['http://dbpedia.org/resource/Antillean_siskin'],
#  'antilophia': ['http://dbpedia.org/resource/Antilophia'],
#  'antioquia bristle tyrant': ['http://dbpedia.org/resource/Antioquia_bristle_tyrant'],
#  'antioquia wren': ['http://dbpedia.org/resource/Antioquia_wren'],
#  'antipodean albatross': ['http://dbpedia.org/resource/Antipodean_albatross'],
#  '(robertson & warham 1992)': ['http://dbpedia.org/resource/Antipodean_albatross'],
#  'diomedea exulans antipodensis': ['http://dbpedia.org/resource/Antipodean_albatross'],
#  'antpecker': ['http://dbpedia.org/resource/Antpecker'],
#  'antrostomus': ['http://dbpedia.org/resource/Antrostomus'],
#  "ants'hillvania": ["http://dbpedia.org/resource/Ants'hillvania"],
#  'anurolimnas': ['http://dbpedia.org/resource/Anurolimnas'],
#  'apalharpactes': ['http://dbpedia.org/resource/Apalharpactes'],
#  'apalis': ['http://dbpedia.org/resource/Apalis'],
#  'apaloderma': ['http://dbpedia.org/resource/Apaloderma'],
#  'apatornis': ['http://dbpedia.org/resource/Apatornis'],
#  'ichthyornis celer (marsh, 1873a)': ['http://dbpedia.org/resource/Apatornis'],
#  'aphelocephala': ['http://dbpedia.org/resource/Aphelocephala'],
#  'aphrastura': ['http://dbpedia.org/resource/Aphrastura'],
#  'apical flycatcher': ['http://dbpedia.org/resource/Apical_flycatcher'],
#  'aplomado falcon': ['http://dbpedia.org/resource/Aplomado_falcon'],
#  'see text': ["http://dbpedia.org/resource/Stejneger's_stonechat"],
#  'aplonis': ['http://dbpedia.org/resource/Aplonis'],
#  'apo sunbird': ['http://dbpedia.org/resource/Apo_sunbird'],
#  "apolinar's wren": ["http://dbpedia.org/resource/Apolinar's_wren"],
#  'apostlebird': ['http://dbpedia.org/resource/Apostlebird'],
#  "appert's tetraka": ["http://dbpedia.org/resource/Appert's_tetraka"],
#  'bernieria apperti': ["http://dbpedia.org/resource/Appert's_tetraka"],
#  'phyllastrephus apperti': ["http://dbpedia.org/resource/Appert's_tetraka"],
#  'apricot-breasted sunbird': ['http://dbpedia.org/resource/Apricot-breasted_sunbird'],
#  'aprosmictus': ['http://dbpedia.org/resource/Aprosmictus'],
#  'apsaravis': ['http://dbpedia.org/resource/Apsaravis'],
#  'apteryx littoralis': ['http://dbpedia.org/resource/Apteryx_littoralis'],
#  'apurímac brush finch': ['http://dbpedia.org/resource/Apurímac_brush_finch'],
#  'apurímac spinetail': ['http://dbpedia.org/resource/Apurímac_spinetail'],
#  'aquatic warbler': ['http://dbpedia.org/resource/Aquatic_warbler'],
#  'aquila (genus)': ['http://dbpedia.org/resource/Aquila_(genus)'],
#  'arabian accentor': ['http://dbpedia.org/resource/Arabian_accentor'],
#  'arabian babbler': ['http://dbpedia.org/resource/Arabian_babbler'],
#  'turdoides squamiceps': ['http://dbpedia.org/resource/Arabian_babbler'],
#  'arabian bustard': ['http://dbpedia.org/resource/Arabian_bustard'],
#  'otis arabs': ['http://dbpedia.org/resource/Arabian_bustard'],
#  'arabian golden sparrow': ['http://dbpedia.org/resource/Arabian_golden_sparrow'],
#  ' auripasser euchlorus': ['http://dbpedia.org/resource/Arabian_golden_sparrow'],
#  ' auripasser luteus euchlorus': ['http://dbpedia.org/resource/Arabian_golden_sparrow'],
#  ' passer luteus euchlorus': ['http://dbpedia.org/resource/Arabian_golden_sparrow'],
#  'arabian golden-winged grosbeak': ['http://dbpedia.org/resource/Arabian_golden-winged_grosbeak'],
#  'rhynchostruthus socotranus percivali': ['http://dbpedia.org/resource/Arabian_golden-winged_grosbeak'],
#  'arabian partridge': ['http://dbpedia.org/resource/Arabian_partridge'],
#  'arabian scops owl': ['http://dbpedia.org/resource/Arabian_scops_owl'],
#  'arabian serin': ['http://dbpedia.org/resource/Arabian_serin'],
#  'serinus rothschildi': ['http://dbpedia.org/resource/Arabian_serin'],
#  'arabian warbler': ['http://dbpedia.org/resource/Arabian_warbler'],
#  'curruca leucomelaena': ['http://dbpedia.org/resource/Arabian_warbler'],
#  'arabian wheatear': ['http://dbpedia.org/resource/Arabian_wheatear'],
#  'aramides': ['http://dbpedia.org/resource/Aramides'],
#  'aratinga': ['http://dbpedia.org/resource/Aratinga'],
#  'araucaria tit-spinetail': ['http://dbpedia.org/resource/Araucaria_tit-spinetail'],
#  'arborophila': ['http://dbpedia.org/resource/Arborophila'],
#  'arborophilinae': ['http://dbpedia.org/resource/Arborophilinae'],
#  'archaeopsittacus': ['http://dbpedia.org/resource/Archaeopsittacus'],
#  'psittacus verreauxii': ['http://dbpedia.org/resource/Archaeopsittacus'],
#  "archbold's newtonia": ["http://dbpedia.org/resource/Archbold's_newtonia"],
#  "archbold's nightjar": ["http://dbpedia.org/resource/Archbold's_nightjar"],
#  "archbold's owlet-nightjar": ["http://dbpedia.org/resource/Archbold's_owlet-nightjar"],
#  'archboldia': ['http://dbpedia.org/resource/Archboldia'],
#  "archer's ground robin": ["http://dbpedia.org/resource/Archer's_ground_robin"],
#  "archer's lark": ["http://dbpedia.org/resource/Archer's_lark"],
#  ' heteromirafra ruddi archeri': ["http://dbpedia.org/resource/Archer's_lark"],
#  ' mirafra archeri': ["http://dbpedia.org/resource/Archer's_lark"],
#  'archilochus (bird)': ['http://dbpedia.org/resource/Archilochus_(bird)'],
#  'arctic tern': ['http://dbpedia.org/resource/Arctic_tern'],
#  'sterna pikei': ['http://dbpedia.org/resource/Arctic_tern'],
#  'sterna portlandica': ['http://dbpedia.org/resource/Arctic_tern'],
#  'arctic warbler': ['http://dbpedia.org/resource/Arctic_warbler'],
#  'ardenna': ['http://dbpedia.org/resource/Ardenna'],
#  'ardeotis': ['http://dbpedia.org/resource/Ardeotis'],
#  'arfak honeyeater': ['http://dbpedia.org/resource/Arfak_honeyeater'],
#  'argentavis': ['http://dbpedia.org/resource/Argentavis'],
#  'argus bare-eye': ['http://dbpedia.org/resource/Argus_bare-eye'],
#  'aripuana antwren': ['http://dbpedia.org/resource/Aripuana_antwren'],
#  'arizona woodpecker': ['http://dbpedia.org/resource/Arizona_woodpecker'],
#  ' picoides arizonae': ['http://dbpedia.org/resource/Arizona_woodpecker'],
#  ' dryobates arizonae': ['http://dbpedia.org/resource/Arizona_woodpecker'],
#  'armchair apocrypha': ['http://dbpedia.org/resource/Armchair_Apocrypha'],
#  'armenian gull': ['http://dbpedia.org/resource/Armenian_gull'],
#  'larus cachinnans armenicus': ['http://dbpedia.org/resource/Armenian_gull'],
#  "arnot's chat": ["http://dbpedia.org/resource/Arnot's_chat"],
#  ' myrmecocichla arnoti': ["http://dbpedia.org/resource/Arnot's_chat"],
#  ' pentholaea arnotti': ["http://dbpedia.org/resource/Arnot's_chat"],
#  'arremon': ['http://dbpedia.org/resource/Arremon'],
#  'arremonops': ['http://dbpedia.org/resource/Arremonops'],
#  'arrow-marked babbler': ['http://dbpedia.org/resource/Arrow-marked_babbler'],
#  'arrowhead piculet': ['http://dbpedia.org/resource/Arrowhead_piculet'],
#  'arrowhead warbler': ['http://dbpedia.org/resource/Arrowhead_warbler'],
#  'dendroica pharetra': ['http://dbpedia.org/resource/Arrowhead_warbler'],
#  'arses (genus)': ['http://dbpedia.org/resource/Arses_(genus)'],
#  'artemisiospiza': ['http://dbpedia.org/resource/Artemisiospiza'],
#  'artisornis': ['http://dbpedia.org/resource/Artisornis'],
#  'ascension crake': ['http://dbpedia.org/resource/Ascension_crake'],
#  'ascension frigatebird': ['http://dbpedia.org/resource/Ascension_frigatebird'],
#  'pelecanus aquilus': ['http://dbpedia.org/resource/Ascension_frigatebird'],
#  "ash's lark": ["http://dbpedia.org/resource/Ash's_lark"],
#  'ash-breasted antbird': ['http://dbpedia.org/resource/Ash-breasted_antbird'],
#  'ash-breasted sierra finch': ['http://dbpedia.org/resource/Ash-breasted_sierra_finch'],
#  'ash-breasted tit-tyrant': ['http://dbpedia.org/resource/Ash-breasted_tit-tyrant'],
#  'ash-browed spinetail': ['http://dbpedia.org/resource/Ash-browed_spinetail'],
#  'ash-throated antwren': ['http://dbpedia.org/resource/Ash-throated_antwren'],
#  'ash-throated casiornis': ['http://dbpedia.org/resource/Ash-throated_casiornis'],
#  'ash-throated crake': ['http://dbpedia.org/resource/Ash-throated_crake'],
#  'porzana albicollis': ['http://dbpedia.org/resource/Ash-throated_crake'],
#  'ash-throated flycatcher': ['http://dbpedia.org/resource/Ash-throated_flycatcher'],
#  'tyrannula cinerascens': ['http://dbpedia.org/resource/Ash-throated_flycatcher'],
#  'tyrannula mexicanus': ['http://dbpedia.org/resource/Ash-throated_flycatcher'],
#  'ash-throated gnateater': ['http://dbpedia.org/resource/Ash-throated_gnateater'],
#  'ash-winged antwren': ['http://dbpedia.org/resource/Ash-winged_antwren'],
#  'terenura spodioptila': ['http://dbpedia.org/resource/Ash-winged_antwren'],
#  'ashy bulbul': ['http://dbpedia.org/resource/Ashy_bulbul'],
#  ' hypsipetes flavala': ['http://dbpedia.org/resource/Ashy_bulbul'],
#  ' hypsipetes flavalus': ['http://dbpedia.org/resource/Ashy_bulbul'],
#  ' microscelis flavala': ['http://dbpedia.org/resource/Ashy_bulbul'],
#  'ashy cisticola': ['http://dbpedia.org/resource/Ashy_cisticola'],
#  'ashy drongo': ['http://dbpedia.org/resource/Ashy_drongo'],
#  'ashy flowerpecker': ['http://dbpedia.org/resource/Ashy_flowerpecker'],
#  'ashy flycatcher': ['http://dbpedia.org/resource/Ashy_flycatcher'],
#  ' fraseria caerulescens ': ['http://dbpedia.org/resource/Ashy_flycatcher'],
#  ' butalis caerulescens hartlaub, 1865': ['http://dbpedia.org/resource/Ashy_flycatcher'],
#  ' muscicapa cinereola  hartlaub & finsch, 1870': ['http://dbpedia.org/resource/Ashy_flycatcher'],
#  ' eopsaltria cinerea cassin, 1857': ['http://dbpedia.org/resource/Ashy_flycatcher'],
#  ' muscicapa cinerea ': ['http://dbpedia.org/resource/Ashy_flycatcher'],
#  ' alseonax cinereus ': ['http://dbpedia.org/resource/Ashy_flycatcher'],
#  ' alseonax ituriensis reichenow, 1908': ['http://dbpedia.org/resource/Ashy_flycatcher'],
#  'ashy gerygone': ['http://dbpedia.org/resource/Ashy_gerygone'],
#  'ashy minivet': ['http://dbpedia.org/resource/Ashy_minivet'],
#  'lanius divaricatus (raffles, 1822)': ['http://dbpedia.org/resource/Ashy_minivet'],
#  'ashy myzomela': ['http://dbpedia.org/resource/Ashy_myzomela'],
#  'ashy prinia': ['http://dbpedia.org/resource/Ashy_prinia'],
#  'burnesia socialis': ['http://dbpedia.org/resource/Ashy_prinia'],
#  'ashy robin': ['http://dbpedia.org/resource/Ashy_robin'],
#  'poecilodryas albispecularis': ['http://dbpedia.org/resource/Ashy_robin'],
#  'ashy storm petrel': ['http://dbpedia.org/resource/Ashy_storm_petrel'],
#  'oceanodroma homochroa': ['http://dbpedia.org/resource/Ashy_storm_petrel'],
#  'ashy tailorbird': ['http://dbpedia.org/resource/Ashy_tailorbird'],
#  'ashy thrush': ['http://dbpedia.org/resource/Ashy_thrush'],
#  'zoothera cinerea': ['http://dbpedia.org/resource/Ashy_thrush'],
#  'ashy tit': ['http://dbpedia.org/resource/Ashy_tit'],
#  'parus cinerascens': ['http://dbpedia.org/resource/Ashy_tit'],
#  'ashy wood pigeon': ['http://dbpedia.org/resource/Ashy_wood_pigeon'],
#  'ashy woodpecker': ['http://dbpedia.org/resource/Ashy_woodpecker'],
#  'ashy woodswallow': ['http://dbpedia.org/resource/Ashy_woodswallow'],
#  'ashy-bellied white-eye': ['http://dbpedia.org/resource/Ashy-bellied_white-eye'],
#  'ashy-breasted flycatcher': ['http://dbpedia.org/resource/Ashy-breasted_flycatcher'],
#  'ashy-faced owl': ['http://dbpedia.org/resource/Ashy-faced_owl'],
#  'ashy-fronted bulbul': ['http://dbpedia.org/resource/Ashy-fronted_bulbul'],
#  ' brachypus cinereifrons': ['http://dbpedia.org/resource/Ashy-fronted_bulbul'],
#  ' pycnonotus plumosus cinereifrons': ['http://dbpedia.org/resource/Ashy-fronted_bulbul'],
#  'ashy-headed babbler': ['http://dbpedia.org/resource/Ashy-headed_babbler'],
#  'ashy-headed goose': ['http://dbpedia.org/resource/Ashy-headed_goose'],
#  'ashy-headed green pigeon': ['http://dbpedia.org/resource/Ashy-headed_green_pigeon'],
#  'ashy-headed greenlet': ['http://dbpedia.org/resource/Ashy-headed_greenlet'],
#  'ashy-headed tyrannulet': ['http://dbpedia.org/resource/Ashy-headed_tyrannulet'],
#  'tyranniscus cinereiceps': ['http://dbpedia.org/resource/Ashy-headed_tyrannulet'],
#  'ashy-throated bush tanager': ['http://dbpedia.org/resource/Ashy-throated_bush_tanager'],
#  'ashy-throated parrotbill': ['http://dbpedia.org/resource/Ashy-throated_parrotbill'],
#  'paradoxornis alphonsianus': ['http://dbpedia.org/resource/Ashy-throated_parrotbill'],
#  'suthora alphonsiana (j.verreaux, 1870)': ['http://dbpedia.org/resource/Ashy-throated_parrotbill'],
# ...
#  'aztec rail': ['http://dbpedia.org/resource/Aztec_rail'],
#  'aztec thrush': ['http://dbpedia.org/resource/Aztec_thrush'],
#  'turdus pinicola': ['http://dbpedia.org/resource/Aztec_thrush'],
#  'zoothera pinicola': ['http://dbpedia.org/resource/Aztec_thrush'],
#  'azuero dove': ['http://dbpedia.org/resource/Azuero_dove'],
#  'azure dollarbird': ['http://dbpedia.org/resource/Azure_dollarbird'],
#  ' eurystomus orientalis azureus': ['http://dbpedia.org/resource/Azure_dollarbird'],
#  'azure gallinule': ['http://dbpedia.org/resource/Azure_gallinule'],
#  'azure jay': ['http://dbpedia.org/resource/Azure_jay'],
#  'azure kingfisher': ['http://dbpedia.org/resource/Azure_kingfisher'],
#  'alcedo azurea': ['http://dbpedia.org/resource/Azure_kingfisher'],
#  'azure tit': ['http://dbpedia.org/resource/Azure_tit'],
#  'parus cyanus': ['http://dbpedia.org/resource/Azure_tit'],
#  'azure-breasted pitta': ['http://dbpedia.org/resource/Azure-breasted_pitta'],
#  'azure-crested flycatcher': ['http://dbpedia.org/resource/Azure-crested_flycatcher'],
#  'azure-crowned hummingbird': ['http://dbpedia.org/resource/Azure-crowned_hummingbird'],
#  'ornismya cyanocephalus lesson, 1829': ['http://dbpedia.org/resource/Azure-crowned_hummingbird'],
#  'azure-hooded jay': ['http://dbpedia.org/resource/Azure-hooded_jay'],
#  'azure-naped jay': ['http://dbpedia.org/resource/Azure-naped_jay'],
#  'azure-shouldered tanager': ['http://dbpedia.org/resource/Azure-shouldered_tanager'],
#  'azure-winged magpie': ['http://dbpedia.org/resource/Azure-winged_magpie'],
#  'cyanopica cyana': ['http://dbpedia.org/resource/Azure-winged_magpie'],
#  'brca mutation': ['http://dbpedia.org/resource/BRCA_mutation'],
#  'babax': ['http://dbpedia.org/resource/Babax'],
#  "bachman's sparrow": ["http://dbpedia.org/resource/Bachman's_sparrow"],
#  'aimophila aestivalis': ["http://dbpedia.org/resource/Bachman's_sparrow"],
#  "bachman's warbler": ["http://dbpedia.org/resource/Bachman's_warbler"],
#  'baeolophus': ['http://dbpedia.org/resource/Baeolophus'],
#  'baeopogon': ['http://dbpedia.org/resource/Baeopogon'],
#  "baer's pochard": ["http://dbpedia.org/resource/Baer's_pochard"],
#  'baglafecht weaver': ['http://dbpedia.org/resource/Baglafecht_weaver'],
#  'bahama mockingbird': ['http://dbpedia.org/resource/Bahama_mockingbird'],
#  'bahama oriole': ['http://dbpedia.org/resource/Bahama_oriole'],
#  'bahama warbler': ['http://dbpedia.org/resource/Bahama_warbler'],
#  'dendroica flavescens': ['http://dbpedia.org/resource/Bahama_warbler'],
#  'setophaga dominica flavescens': ['http://dbpedia.org/resource/Bahama_warbler'],
#  'dendroica dominica flavescens': ['http://dbpedia.org/resource/Bahama_warbler'],
#  'bahama woodstar': ['http://dbpedia.org/resource/Bahama_woodstar'],
#  'philodice evelynae': ['http://dbpedia.org/resource/Bahama_woodstar'],
#  'bahama yellowthroat': ['http://dbpedia.org/resource/Bahama_yellowthroat'],
#  'bahaman caracara': ['http://dbpedia.org/resource/Bahaman_caracara'],
#  'polyborus creightoni': ['http://dbpedia.org/resource/Bahaman_caracara'],
#  'bahia antwren': ['http://dbpedia.org/resource/Bahia_antwren'],
#  'bahia spinetail': ['http://dbpedia.org/resource/Bahia_spinetail'],
#  'synallaxis whitneyi': ['http://dbpedia.org/resource/Bahia_spinetail'],
#  'bahia tapaculo': ['http://dbpedia.org/resource/Bahia_tapaculo'],
#  'scytalopus psychopompus': ['http://dbpedia.org/resource/Bahia_tapaculo'],
#  'bahia tyrannulet': ['http://dbpedia.org/resource/Bahia_tyrannulet'],
#  'bahian mouse-colored tapaculo': ['http://dbpedia.org/resource/Bahian_mouse-colored_tapaculo'],
#  'baikal bullfinch': ['http://dbpedia.org/resource/Baikal_bullfinch'],
#  'pyrrhula cineracea': ['http://dbpedia.org/resource/Baikal_bullfinch'],
#  'baikal teal': ['http://dbpedia.org/resource/Baikal_teal'],
#  'anas formosa (georgi, 1775)': ['http://dbpedia.org/resource/Baikal_teal'],
#  "baird's flycatcher": ["http://dbpedia.org/resource/Baird's_flycatcher"],
#  "baird's sandpiper": ["http://dbpedia.org/resource/Baird's_sandpiper"],
#  'actodromas bairdii': ["http://dbpedia.org/resource/Baird's_sandpiper"],
#  'erolia bairdii': ["http://dbpedia.org/resource/Baird's_sandpiper"],
#  "baird's sparrow": ["http://dbpedia.org/resource/Baird's_sparrow"],
#  'passerculus bairdii': ["http://dbpedia.org/resource/Baird's_sparrow"],
#  "baird's trogon": ["http://dbpedia.org/resource/Baird's_trogon"],
#  'bald eagle': ['http://dbpedia.org/resource/Bald_eagle'],
#  'falco leucocephalus (linnaeus, 1766)': ['http://dbpedia.org/resource/Bald_eagle'],
#  'bald parrot': ['http://dbpedia.org/resource/Bald_parrot'],
#  ' pionopsitta aurantiocephala (gaban-lima, raposo & hofling, 2002)': ['http://dbpedia.org/resource/Bald_parrot'],
#  ' gypopsitta aurantiocephala': ['http://dbpedia.org/resource/Bald_parrot'],
#  'baldwin family': ['http://dbpedia.org/resource/Baldwin_family'],
#  'balearic shearwater': ['http://dbpedia.org/resource/Balearic_shearwater'],
#  'puffinus puffinus mauretanicus': ['http://dbpedia.org/resource/Balearic_shearwater'],
#  'puffinus yelkouan mauretanicus': ['http://dbpedia.org/resource/Balearic_shearwater'],
#  'balearic warbler': ['http://dbpedia.org/resource/Balearic_warbler'],
#  'bali myna': ['http://dbpedia.org/resource/Bali_myna'],
#  'balicassiao': ['http://dbpedia.org/resource/Balicassiao'],
#  'corvus balicassius': ['http://dbpedia.org/resource/Balicassiao'],
#  'balista': ['http://dbpedia.org/resource/Balista'],
#  'balsas screech owl': ['http://dbpedia.org/resource/Balsas_screech_owl'],
#  'otus seductus r. t. moore, 1941': ['http://dbpedia.org/resource/Balsas_screech_owl'],
#  'baltimore oriole': ['http://dbpedia.org/resource/Baltimore_oriole'],
#  'coracias galbula ': ['http://dbpedia.org/resource/Baltimore_oriole'],
#  'oriolus galbula': ['http://dbpedia.org/resource/Baltimore_oriole'],
#  'bamboo antshrike': ['http://dbpedia.org/resource/Bamboo_antshrike'],
#  'bamboo foliage-gleaner': ['http://dbpedia.org/resource/Bamboo_foliage-gleaner'],
#  'automolus dorsalis': ['http://dbpedia.org/resource/Bamboo_foliage-gleaner'],
#  'bamboo warbler': ['http://dbpedia.org/resource/Bamboo_warbler'],
#  'bradypterus alfredi': ['http://dbpedia.org/resource/Bamboo_warbler'],
#  'bamboo woodpecker': ['http://dbpedia.org/resource/Bamboo_woodpecker'],
#  'bambusicola': ['http://dbpedia.org/resource/Bambusicola'],
#  'bamenda apalis': ['http://dbpedia.org/resource/Bamenda_apalis'],
#  'ban on sharia law': ['http://dbpedia.org/resource/Ban_on_sharia_law'],
#  'bananal antbird': ['http://dbpedia.org/resource/Bananal_antbird'],
#  'bananaquit': ['http://dbpedia.org/resource/Bananaquit'],
#  'certhia flaveola ': ['http://dbpedia.org/resource/Bananaquit'],
#  'certhiola martinicensis': ['http://dbpedia.org/resource/Bananaquit'],
#  'certhiola dominicana': ['http://dbpedia.org/resource/Bananaquit'],
#  'band-backed wren': ['http://dbpedia.org/resource/Band-backed_wren'],
#  'band-bellied crake': ['http://dbpedia.org/resource/Band-bellied_crake'],
#  'porzana paykullii': ['http://dbpedia.org/resource/Band-bellied_crake'],
#  'band-bellied owl': ['http://dbpedia.org/resource/Band-bellied_owl'],
#  'band-rumped swift': ['http://dbpedia.org/resource/Band-rumped_swift'],
#  'band-tailed antbird': ['http://dbpedia.org/resource/Band-tailed_antbird'],
#  'band-tailed antshrike': ['http://dbpedia.org/resource/Band-tailed_antshrike'],
#  'sakesphorus melanothorax': ['http://dbpedia.org/resource/Band-tailed_antshrike'],
#  'band-tailed antwren': ['http://dbpedia.org/resource/Band-tailed_antwren'],
#  'band-tailed barbthroat': ['http://dbpedia.org/resource/Band-tailed_barbthroat'],
#  'band-tailed earthcreeper': ['http://dbpedia.org/resource/Band-tailed_earthcreeper'],
#  'eremobius phoenicurus': ['http://dbpedia.org/resource/Band-tailed_earthcreeper'],
#  'band-tailed fruiteater': ['http://dbpedia.org/resource/Band-tailed_fruiteater'],
#  'band-tailed guan': ['http://dbpedia.org/resource/Band-tailed_guan'],
#  'band-tailed hornero': ['http://dbpedia.org/resource/Band-tailed_hornero'],
#  'band-tailed manakin': ['http://dbpedia.org/resource/Band-tailed_manakin'],
#  'band-tailed nighthawk': ['http://dbpedia.org/resource/Band-tailed_nighthawk'],
#  'band-tailed oropendola': ['http://dbpedia.org/resource/Band-tailed_oropendola'],
#  'ocyalus latirostris': ['http://dbpedia.org/resource/Band-tailed_oropendola'],
#  'psarocolius latirostris': ['http://dbpedia.org/resource/Band-tailed_oropendola'],
#  'band-tailed seedeater': ['http://dbpedia.org/resource/Band-tailed_seedeater'],
#  'linaria analis': ['http://dbpedia.org/resource/Band-tailed_seedeater'],
#  'band-tailed sierra finch': ['http://dbpedia.org/resource/Band-tailed_sierra_finch'],
#  ' fringilla alaudina (von kittlitz, 1833)': ['http://dbpedia.org/resource/Band-tailed_sierra_finch'],
#  ' corydospiza alaudina': ['http://dbpedia.org/resource/Band-tailed_sierra_finch'],
#  ' phrygilus alaudinus': ['http://dbpedia.org/resource/Band-tailed_sierra_finch'],
#  ' porphyrospiza alaudina': ['http://dbpedia.org/resource/Band-tailed_sierra_finch'],
#  " rhopospina alaudina''": ['http://dbpedia.org/resource/Band-tailed_sierra_finch'],
#  'band-winged nightjar': ['http://dbpedia.org/resource/Band-winged_nightjar'],
#  'banda myzomela': ['http://dbpedia.org/resource/Banda_myzomela'],
#  'banded antbird': ['http://dbpedia.org/resource/Banded_antbird'],
#  'banded barbet': ['http://dbpedia.org/resource/Banded_barbet'],
#  'banded bay cuckoo': ['http://dbpedia.org/resource/Banded_bay_cuckoo'],
#  'penthoceryx sonneratii': ['http://dbpedia.org/resource/Banded_bay_cuckoo'],
#  'banded broadbill': ['http://dbpedia.org/resource/Banded_broadbill'],
#  'banded cotinga': ['http://dbpedia.org/resource/Banded_cotinga'],
#  'banded fruit dove': ['http://dbpedia.org/resource/Banded_fruit_dove'],
#  'banded green sunbird': ['http://dbpedia.org/resource/Banded_green_sunbird'],
#  'banded ground cuckoo': ['http://dbpedia.org/resource/Banded_ground_cuckoo'],
#  'banded honeyeater': ['http://dbpedia.org/resource/Banded_honeyeater'],
#  ' certhionyx pectoralis': ['http://dbpedia.org/resource/Banded_honeyeater'],
#  'banded kestrel': ['http://dbpedia.org/resource/Banded_kestrel'],
#  'banded kingfisher': ['http://dbpedia.org/resource/Banded_kingfisher'],
#  'banded martin': ['http://dbpedia.org/resource/Banded_martin'],
#  'banded parisoma': ['http://dbpedia.org/resource/Banded_parisoma'],
#  ' parisoma boehmi': ['http://dbpedia.org/resource/Banded_parisoma'],
#  'banded penguin': ['http://dbpedia.org/resource/Banded_penguin'],
#  'banded pitta': ['http://dbpedia.org/resource/Banded_pitta'],
#  'banded prinia': ['http://dbpedia.org/resource/Banded_prinia'],
#  'banded quail': ['http://dbpedia.org/resource/Banded_quail'],
#  'banded stilt': ['http://dbpedia.org/resource/Banded_stilt'],
#  'cladorhynchus australis (lawson)': ['http://dbpedia.org/resource/Banded_stilt'],
#  'cladorhynchus leucocephalus rottnesti (mathews)': ['http://dbpedia.org/resource/Banded_stilt'],
#  'himantopus palmatus (gould)': ['http://dbpedia.org/resource/Banded_stilt'],
#  'leptorhynchus pectoralis (du bus, 1835)': ['http://dbpedia.org/resource/Banded_stilt'],
#  'recurvirostra leucocephala (vieillot)': ['http://dbpedia.org/resource/Banded_stilt'],
#  'recurvirostra orientalis (cuvier, 1816)': ['http://dbpedia.org/resource/Banded_stilt'],
#  'xiphidiorhynchus pectoralis (ludwig reichenbach, 1845)': ['http://dbpedia.org/resource/Banded_stilt'],
#  'banded wattle-eye': ['http://dbpedia.org/resource/Banded_wattle-eye'],
#  'banded whiteface': ['http://dbpedia.org/resource/Banded_whiteface'],
#  'xerophila nigricincta north': ['http://dbpedia.org/resource/Banded_whiteface'],
#  'banded woodpecker': ['http://dbpedia.org/resource/Banded_woodpecker'],
#  'picus mineaceus': ['http://dbpedia.org/resource/Banded_woodpecker'],
#  'banded wren': ['http://dbpedia.org/resource/Banded_wren'],
#  ' thryothorus pleurostictus': ['http://dbpedia.org/resource/Banded_wren'],
#  ' pheugopedius pleurostictus': ['http://dbpedia.org/resource/Banded_wren'],
#  'banded yellow robin': ['http://dbpedia.org/resource/Banded_yellow_robin'],
#  'poecilodryas placens': ['http://dbpedia.org/resource/Banded_yellow_robin'],
#  'banggai fruit dove': ['http://dbpedia.org/resource/Banggai_fruit_dove'],
#  'bangsia': ['http://dbpedia.org/resource/Bangsia'],
#  'bangwa forest warbler': ['http://dbpedia.org/resource/Bangwa_forest_warbler'],
#  'bank cormorant': ['http://dbpedia.org/resource/Bank_cormorant'],
#  'bank myna': ['http://dbpedia.org/resource/Bank_myna'],
#  'banking regulation act, 1949': ['http://dbpedia.org/resource/Banking_Regulation_Act,_1949'],
#  "bannerman's shearwater": ["http://dbpedia.org/resource/Bannerman's_shearwater"],
#  "bannerman's sunbird": ["http://dbpedia.org/resource/Bannerman's_sunbird"],
#  'nectarinia bannermani': ["http://dbpedia.org/resource/Bannerman's_sunbird"],
#  "bannerman's turaco": ["http://dbpedia.org/resource/Bannerman's_turaco"],
#  "bannerman's weaver": ["http://dbpedia.org/resource/Bannerman's_weaver"],
#  'baptornis': ['http://dbpedia.org/resource/Baptornis'],
#  'parascaniornis (lambrecht, 1933)': ['http://dbpedia.org/resource/Baptornis'],
#  'bar juchne': ['http://dbpedia.org/resource/Bar_Juchne'],
#  'bar-backed partridge': ['http://dbpedia.org/resource/Bar-backed_partridge'],
#  'bar-bellied cuckooshrike': ['http://dbpedia.org/resource/Bar-bellied_cuckooshrike'],
#  'bar-bellied pitta': ['http://dbpedia.org/resource/Bar-bellied_pitta'],
#  'pitta elliotii': ['http://dbpedia.org/resource/Bar-bellied_pitta'],
#  'bar-bellied woodcreeper': ['http://dbpedia.org/resource/Bar-bellied_woodcreeper'],
#  'bar-bellied woodpecker': ['http://dbpedia.org/resource/Bar-bellied_woodpecker'],
#  'bar-breasted honeyeater': ['http://dbpedia.org/resource/Bar-breasted_honeyeater'],
#  'bar-breasted piculet': ['http://dbpedia.org/resource/Bar-breasted_piculet'],
#  'bar-crested antshrike': ['http://dbpedia.org/resource/Bar-crested_antshrike'],
#  'bar-headed goose': ['http://dbpedia.org/resource/Bar-headed_goose'],
#  'anser indica': ['http://dbpedia.org/resource/Bar-headed_goose'],
#  'eulabeia indica': ['http://dbpedia.org/resource/Bar-headed_goose'],
#  'bar-necked cuckoo-dove': ['http://dbpedia.org/resource/Bar-necked_cuckoo-dove'],
#  'bar-tailed cuckoo-dove': ['http://dbpedia.org/resource/Bar-tailed_cuckoo-dove'],
#  'bar-tailed godwit': ['http://dbpedia.org/resource/Bar-tailed_godwit'],
#  'scolopax lapponica (linnaeus, 1758)': ['http://dbpedia.org/resource/Bar-tailed_godwit'],
#  'bar-tailed lark': ['http://dbpedia.org/resource/Bar-tailed_lark'],
#  ' ammomanes cincturus': ['http://dbpedia.org/resource/Bar-tailed_lark'],
#  ' ammomanes cinturus': ['http://dbpedia.org/resource/Bar-tailed_lark'],
#  ' melanocorypha cinctura': ['http://dbpedia.org/resource/Bar-tailed_lark'],
#  'bar-tailed treecreeper': ['http://dbpedia.org/resource/Bar-tailed_treecreeper'],
#  'bar-tailed trogon': ['http://dbpedia.org/resource/Bar-tailed_trogon'],
#  'hapaloderma vittatum': ['http://dbpedia.org/resource/Bar-tailed_trogon'],
#  'bar-throated apalis': ['http://dbpedia.org/resource/Bar-throated_apalis'],
#  'bar-throated minla': ['http://dbpedia.org/resource/Bar-throated_minla'],
#  'chrysominla strigula': ['http://dbpedia.org/resource/Bar-throated_minla'],
#  'minla strigula': ['http://dbpedia.org/resource/Bar-throated_minla'],
#  'bar-winged flycatcher-shrike': ['http://dbpedia.org/resource/Bar-winged_flycatcher-shrike'],
#  'hemipus picaecolor': ['http://dbpedia.org/resource/Bar-winged_flycatcher-shrike'],
#  'muscicapa picata': ['http://dbpedia.org/resource/Bar-winged_flycatcher-shrike'],
#  'bar-winged oriole': ['http://dbpedia.org/resource/Bar-winged_oriole'],
#  'bar-winged prinia': ['http://dbpedia.org/resource/Bar-winged_prinia'],
#  'bar-winged rail': ['http://dbpedia.org/resource/Bar-winged_rail'],
#  'hypotaenidia poeciloptera': ['http://dbpedia.org/resource/Bar-winged_rail'],
#  'gallirallus poecilopterus': ['http://dbpedia.org/resource/Bar-winged_rail'],
#  'bar-winged weaver': ['http://dbpedia.org/resource/Bar-winged_weaver'],
#  'bar-winged wood wren': ['http://dbpedia.org/resource/Bar-winged_wood_wren'],
#  'bar-winged wren-babbler': ['http://dbpedia.org/resource/Bar-winged_wren-babbler'],
#  'pnoepyga troglodytoides': ['http://dbpedia.org/resource/Bar-winged_wren-babbler'],
#  ...}

# %% [markdown]
# ### Función 'birds'

# %% [markdown]
# La siguiente función utiliza la  función *get_close_matches* de la librería *difflib* para que para cada entidad encuentre el string más similar (si es que lo hay) dentro de la lista de especies:

# %%
import difflib

def birds(entities,species):

    
    entities=list(entities[0])

    results={}
    
    for ent in tqdm.tqdm(entities):

        splited_entity=ent.split(" ")
        
        # Esto es un filtro para descartar posibles entidades formadas solo por adverbios, preposiciones, etc.
        if len(splited_entity)==1:
            doc=nlp(splited_entity[0])

            token=[token for token in doc][0]

            filter_=["PROPN","NOUN"]

            if token.pos_ not in filter_:
                    continue

        
        match=difflib.get_close_matches(ent.lower(), species.keys(), cutoff=0.8)

        
        # si se encuentra un match, lo guardamos
        if len(match) !=0:
            results[ent]=[match[0],species[match[0]][0]]
            
            
    return(results)

# %%
results=pd.DataFrame(ents).apply(np.vectorize(birds),species=species,axis=1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 23.81it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 31.23it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 25.25it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 25.64it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 36.69it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 39.22it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 41.65it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 40.81it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 24.80it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 25.68it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 45/45 [00:01<00:00, 24.10it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 45/45 [00:01<00:00, 24.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 18.11it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 17.13it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 12.14it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 10.10it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 15.38it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 13.16it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11.41it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 13.76it/s]

# %%
for i in range(0,len(results)):
    print("-"*100)
    print(data.publications[i])
    print(" ")
    pprint.pprint(results[i][0])
    print(" ")
# Out:
# ----------------------------------------------------------------------------------------------------
# pub_1.txt
#
# {'Common Teal': ['common tern', 'http://dbpedia.org/resource/Common_tern']}
#
# ----------------------------------------------------------------------------------------------------
# pub_10.txt
#
# {}
#
# ----------------------------------------------------------------------------------------------------
# pub_2.txt
#
# {}
#
# ----------------------------------------------------------------------------------------------------
# pub_3.txt
#
# {}
#
# ----------------------------------------------------------------------------------------------------
# pub_4.txt
#
# {'American Bittern': ['american bittern',
#                       'http://dbpedia.org/resource/American_bittern'],
#  'Egrets': ['egret', 'http://dbpedia.org/resource/Egret'],
#  'eBird': ['seabird', 'http://dbpedia.org/resource/Seabird']}
#
# ----------------------------------------------------------------------------------------------------
# pub_5.txt
#
# {'American Robin': ['american robin',
#                     'http://dbpedia.org/resource/American_robin'],
#  'CINEREOUS': ['cinereous tit', 'http://dbpedia.org/resource/Cinereous_tit'],
#  'GREAT SKUAS': ['great skua', 'http://dbpedia.org/resource/Great_skua'],
#  'Redlegged Thrush': ['red-legged thrush',
#                       'http://dbpedia.org/resource/Red-legged_thrush'],
#  'Those Balearic Shearwaters': ['balearic shearwater',
#                                 'http://dbpedia.org/resource/Balearic_shearwater']}
#
# ----------------------------------------------------------------------------------------------------
# pub_6.txt
#
# {'COLLARED INCA': ['collared inca',
#                    'http://dbpedia.org/resource/Collared_inca'],
#  'HUMBOLDT PENGUIN': ['humboldt penguin',
#                       'http://dbpedia.org/resource/Humboldt_penguin'],
#  'LADDERWINGED NIGHTJAR': ['ladder-tailed nightjar',
#                            'http://dbpedia.org/resource/Ladder-tailed_nightjar'],
#  'Puna Plover': ['puna plover', 'http://dbpedia.org/resource/Puna_plover'],
#  'REDLEGGED CORMORANT': ['reed cormorant',
#                          'http://dbpedia.org/resource/Reed_cormorant'],
#  'hummingbird': ['hummingbird', 'http://dbpedia.org/resource/Hummingbird'],
#  'the BLUEHEADED PARROTS': ['blue-headed parrot',
#                             'http://dbpedia.org/resource/Blue-headed_parrot']}
#
# ----------------------------------------------------------------------------------------------------
# pub_7.txt
#
# {'Collared Sparrowhawk': ['collared sparrowhawk',
#                           'http://dbpedia.org/resource/Collared_sparrowhawk'],
#  'House Sparrows': ['house sparrow',
#                     'http://dbpedia.org/resource/House_sparrow'],
#  'Musk Lorikeet': ['musk lorikeet',
#                    'http://dbpedia.org/resource/Musk_lorikeet'],
#  'Purplecrowned Lorikeets': ['purple-crowned lorikeet',
#                              'http://dbpedia.org/resource/Purple-crowned_lorikeet'],
#  'Rainbow Lorikeet': ['rainbow lorikeet',
#                       'http://dbpedia.org/resource/Rainbow_lorikeet']}
#
# ----------------------------------------------------------------------------------------------------
# pub_8.txt
#
# {'Lovebird': ['ovenbird', 'http://dbpedia.org/resource/Ovenbird']}
#
# ----------------------------------------------------------------------------------------------------
# pub_9.txt
#
# {'Australian Ringneck Parrots': ['australian ringneck',
#                                  'http://dbpedia.org/resource/Australian_ringneck'],
#  'Eremophila': ['drymophila', 'http://dbpedia.org/resource/Drymophila']}

# %% [markdown]
# Podemos ver que , aunque sea un proceso bastante eficiente y que consigue detectar algunas especies, hay publicaciones en las que no es capaz de extraer nada, detecta poco o  directamente saca resultados erróneos.
#
# El problema está en el paso inicial: el filtrado de entidades elimina demasiada información relevante, por lo que hay que pensar un método en el que no sea necesario filtrar parte del texto.

# %% [markdown]
# ## Segunda opción: Utilizar el texto en crudo

# %% [markdown]
# La función *get_close_matches* tiene como inputs una palabra de interés y una lista de strings de donde queremos extraer la palabra más similar, lo cual nos obliga a tokenizar el texto. Esto supone un reto en el caso en el que el string de interés está formado por dos o más palabras.
#
# Se ha llegado a la siguiente solución:

# %%
def birds(file,species):
    
    # diccionario donde guardaremos los resultados 
    matches={}
    
    text=open(file,"r",encoding="utf-8").read().split("---")[-1]
    
    #limpiamos el texto de signos de puntuación, números, mayúsculas y saltos de página
    text_tokens=text.translate(str.maketrans("","",string.punctuation)).translate(str.maketrans("","",string.digits)).lower().split()

   
    # iniciamos un bucle que recorrerá todas las especies de pájaro encontradas en la Dbpedia
    
    for sp in tqdm.tqdm(species.keys()):
        
        # definimos el parámetro beg (de beggining) cuya utilidad veremos más adelante
        beg=0
        
        # limpiamos el nombre de la especie de pájaro como se ha hecho con el texto
        sp_trans=sp.translate(str.maketrans("","",string.punctuation)).translate(str.maketrans("","",string.digits)).strip().split("(")[0]
        
        # miramos por cuántas palabras está formado el string de la especie de pájaro
        sp_len=len(sp_trans.split())
        
        # en el caso de que sea una única palabra, bucamos el string más similar dentro de la lista de tokens de la publicación
        if sp_len==1:
            
            # Nota: el parámetro 'cutoff' establece un límite en la similitud que han de tener el input y el match. Imponemos un límite bastante alto.
            
            match=difflib.get_close_matches(sp_trans,text_tokens,cutoff=0.87)
            
            #si se encuentra algún match, se guarda en el diccionario : el match como llave y la especie de pájaro junto a su enlace de la dbpedia como valor
            
            if len(match) !=0:
                    matches[match[0]]=[sp, species[sp][0]]
        
        # caso en el que esté formado por dos o más palabras. Nota: Suponemos que el nombre del pájaro estará compuesto como máximo por 4.
        if sp_len<=4 and sp_len>1:
            
            #iniciamos un bucle infinito
            while True:
                
                
                # dependiendo del número de palabras, agrupamos los strings del texto tokenizado de 2 en 2, 3 en 3 o 4 en 4
                
                #aquí entra en juego el parámetro 'beg': debemos contemplar todas las posibilidades. Por ejemplo, en el caso de que 
                # estemos buscando la especie 'red cormorant' y la frase que lo menciona dentro del texto es 'I saw a red cormorant in the countryside', 
                # la primera agrupación que se hará será ["I saw","a red", "cormorant in", ...], lo cual nos impide hacer el match que buscamos. 
                # El parámeto 'beg' desplaza una posición la agrupación, por lo que en la siguiente iteración tendremos ["saw a", "red cormorant", ...], 
                # y ya podremos hacer el match sin problemas.
                
                
                
                if sp_len==2:
                    new_text=[i+" "+j for i,j in zip(text_tokens[beg::2], text_tokens[beg+1::2])]
                if sp_len==3:
                    new_text=[i+" "+j+" "+k for i,j,k in zip(text_tokens[beg::3], text_tokens[beg+1::3],text_tokens[beg+2::3])]
                if sp_len==4:
                    new_text=[i+" "+j+" "+k+" "+z for i,j,k,z in zip(text_tokens[beg::4], text_tokens[beg+1::4],text_tokens[beg+2::4],text_tokens[beg+3::4])]

                
                # Se busca el match con el nuevo texto con los strings agrupados:
                
                match=difflib.get_close_matches(sp_trans,new_text,cutoff=0.87)
                
                # En el caso de que este se encuentre, lo guardamos y detenemos el loop
                if len(match) !=0:
                    matches[match[0]]=[sp, species[sp][0]]
                    break
                    
                # si no, se mira si 'beg' ha llegado a su límite (número de palabras de sp; precisamente el número de combinaciones posibles). Si es así, se detiene el bucle,
                # en caso contrario se suma uno a 'beg'.
                
                else:
                    if beg==sp_len:
                        break
                    else:
                        beg +=1
                    
               
                
    return(matches)

# %% [markdown]
# Aplicamos la función:

# %%
results=data.apply(np.vectorize(birds), species=species, axis=1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 16286/16286 [00:13<00:00, 1166.72it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 16286/16286 [00:12<00:00, 1297.16it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 16286/16286 [01:26<00:00, 189.33it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 16286/16286 [01:28<00:00, 183.96it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 16286/16286 [01:04<00:00, 252.42it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 16286/16286 [01:16<00:00, 212.75it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 16286/16286 [00:33<00:00, 492.83it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 16286/16286 [00:32<00:00, 501.90it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 16286/16286 [03:30<00:00, 77.51it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 16286/16286 [02:20<00:00, 115.67it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 16286/16286 [07:06<00:00, 38.17it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 16286/16286 [03:34<00:00, 75.76it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 16286/16286 [01:24<00:00, 193.56it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 16286/16286 [01:26<00:00, 188.44it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 16286/16286 [00:17<00:00, 954.50it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 16286/16286 [00:16<00:00, 958.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 16286/16286 [00:10<00:00, 1485.39it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 16286/16286 [00:12<00:00, 1304.16it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 16286/16286 [00:16<00:00, 997.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 16286/16286 [00:16<00:00, 995.52it/s]

# %%
results.to_pickle("results.pkl")

# %%
results=pd.read_pickle("results.pkl")

# %%
for i in range(0,len(results)):
    print(" ")
    ppr.pprint(results.iloc[i][0])
    print(" ")
    print("-"*40)
# Out:
#
# {'greenwinged teal': ['green-winged teal',
#                       'http://dbpedia.org/resource/Green-winged_teal']}
#
# ----------------------------------------
#
# {'cockatoos': ['cockatoo', 'http://dbpedia.org/resource/Cockatoo'],
#  'parrots': ['parrot', 'http://dbpedia.org/resource/Parrot'],
#  'species': ['species:', 'http://dbpedia.org/resource/Ludiortyx']}
#
# ----------------------------------------
#
# {'gull': ['gull', 'http://dbpedia.org/resource/Gull'],
#  'hope': ['(hope, 2002)', 'http://dbpedia.org/resource/Lamarqueavis'],
#  'peregrine falcon': ['peregrine falcon',
#                       'http://dbpedia.org/resource/Peregrine_falcon'],
#  'ringbilled gull': ['ring-billed gull',
#                      'http://dbpedia.org/resource/Ring-billed_gull']}
#
# ----------------------------------------
#
# {'brant': ['branta', 'http://dbpedia.org/resource/Branta'],
#  'gull': ['gull', 'http://dbpedia.org/resource/Gull'],
#  'iceland gull': ['iceland gull', 'http://dbpedia.org/resource/Iceland_gull']}
#
# ----------------------------------------
#
# {'american bittern': ['american bittern',
#                       'http://dbpedia.org/resource/American_bittern'],
#  'blackcrowned nightherons of': ['black-crowned night heron',
#                                  'http://dbpedia.org/resource/Black-crowned_night_heron'],
#  'bonapartes': ['(bonaparte, 1855)',
#                 'http://dbpedia.org/resource/Trocaz_pigeon'],
#  'bonapartes gull': ["bonaparte's gull",
#                      "http://dbpedia.org/resource/Bonaparte's_gull"],
#  'common terns': ['common tern', 'http://dbpedia.org/resource/Common_tern'],
#  'ct': ['c957t', 'http://dbpedia.org/resource/C957T'],
#  'egrets': ['egret', 'http://dbpedia.org/resource/Egret'],
#  'glossy ibis': ['glossy ibis', 'http://dbpedia.org/resource/Glossy_ibis'],
#  'great horned owls': ['great horned owl',
#                        'http://dbpedia.org/resource/Great_horned_owl'],
#  'gull': ['gull', 'http://dbpedia.org/resource/Gull'],
#  'hawk': ['hawk', 'http://dbpedia.org/resource/Hawk'],
#  'hopes': ['(hope, 2002)', 'http://dbpedia.org/resource/Lamarqueavis'],
#  'laughing gulls': ['laughing gull',
#                     'http://dbpedia.org/resource/Laughing_gull'],
#  'least sandpiper': ['least sandpiper',
#                      'http://dbpedia.org/resource/Least_sandpiper'],
#  'little blue heron': ['little blue heron',
#                        'http://dbpedia.org/resource/Little_blue_heron'],
#  'many bird': ['manu (bird)', 'http://dbpedia.org/resource/Manu_(bird)'],
#  'marsh wren': ['marsh wren', 'http://dbpedia.org/resource/Marsh_wren'],
#  'nelsons sparrow': ["nelson's sparrow",
#                      "http://dbpedia.org/resource/Nelson's_sparrow"],
#  'passers': ['passer', 'http://dbpedia.org/resource/Passer'],
#  'saltmarsh sparrow': ['saltmarsh sparrow',
#                        'http://dbpedia.org/resource/Saltmarsh_sparrow'],
#  'scarlet tanager': ['scarlet tanager',
#                      'http://dbpedia.org/resource/Scarlet_tanager'],
#  'scoters': ['scoter', 'http://dbpedia.org/resource/Scoter'],
#  'species': ['species:', 'http://dbpedia.org/resource/Ludiortyx'],
#  'surf scoters': ['surf scoter', 'http://dbpedia.org/resource/Surf_scoter'],
#  'swainsons thrushes': ["swainson's thrush",
#                         "http://dbpedia.org/resource/Swainson's_thrush"],
#  'terns': ['tern', 'http://dbpedia.org/resource/Tern'],
#  'tiller': ['triller', 'http://dbpedia.org/resource/Triller'],
#  'yellowbellied sapsucker': ['yellow-bellied sapsucker',
#                              'http://dbpedia.org/resource/Yellow-bellied_sapsucker']}
#
# ----------------------------------------
#
# {'alpine accentors': ['alpine accentor',
#                       'http://dbpedia.org/resource/Alpine_accentor'],
#  'american robin': ['american robin',
#                     'http://dbpedia.org/resource/American_robin'],
#  'and sandgrouse': ['painted sandgrouse',
#                     'http://dbpedia.org/resource/Painted_sandgrouse'],
#  'balearic shearwater': ['balearic shearwater',
#                          'http://dbpedia.org/resource/Balearic_shearwater'],
#  'blackheaded gulls': ['black-headed gull',
#                        'http://dbpedia.org/resource/Black-headed_gull'],
#  'bonelli’s eagles': ["bonelli's eagle",
#                       "http://dbpedia.org/resource/Bonelli's_eagle"],
#  'both': [' botha', 'http://dbpedia.org/resource/Spizocorys'],
#  'common buzzard': ['common buzzard',
#                     'http://dbpedia.org/resource/Common_buzzard'],
#  'common redshank': ['common redshank',
#                      'http://dbpedia.org/resource/Common_redshank'],
#  'common ringed plover': ['common ringed plover',
#                           'http://dbpedia.org/resource/Common_ringed_plover'],
#  'corn bunting': ['corn bunting', 'http://dbpedia.org/resource/Corn_bunting'],
#  'cory’s shearwaters': ["cory's shearwater",
#                         "http://dbpedia.org/resource/Cory's_shearwater"],
#  'eagles': ['eagle', 'http://dbpedia.org/resource/Eagle'],
#  'eurasian dotterel': ['eurasian dotterel',
#                        'http://dbpedia.org/resource/Eurasian_dotterel'],
#  'eurasian sparrowhawk': ['eurasian sparrowhawk',
#                           'http://dbpedia.org/resource/Eurasian_sparrowhawk'],
#  'gannets': ['gannet', 'http://dbpedia.org/resource/Gannet'],
#  'garden warlber': ['garden warbler',
#                     'http://dbpedia.org/resource/Garden_warbler'],
#  'genus': ['genus:', 'http://dbpedia.org/resource/Ludiortyx'],
#  'great shearwater': ['great shearwater',
#                       'http://dbpedia.org/resource/Great_shearwater'],
#  'great skuas': ['great skua', 'http://dbpedia.org/resource/Great_skua'],
#  'ground i': ['ground tit', 'http://dbpedia.org/resource/Ground_tit'],
#  'gulls': ['gull', 'http://dbpedia.org/resource/Gull'],
#  'hawk': ['hawk', 'http://dbpedia.org/resource/Hawk'],
#  'hen harrier': ['hen harrier', 'http://dbpedia.org/resource/Hen_harrier'],
#  'kentish plover': ['kentish plover',
#                     'http://dbpedia.org/resource/Kentish_plover'],
#  'larks': ['lark', 'http://dbpedia.org/resource/Lark'],
#  'longeared owl': ['long-eared owl',
#                    'http://dbpedia.org/resource/Long-eared_owl'],
#  'meadow pipit': ['meadow pipit', 'http://dbpedia.org/resource/Meadow_pipit'],
#  'northern gannets': ['northern gannet',
#                       'http://dbpedia.org/resource/Northern_gannet'],
#  'northern lapwing': ['southern lapwing',
#                       'http://dbpedia.org/resource/Southern_lapwing'],
#  'of european goldenplovers': ['european golden plover',
#                                'http://dbpedia.org/resource/European_golden_plover'],
#  'our american goldenplovers': ['american golden plover',
#                                 'http://dbpedia.org/resource/American_golden_plover'],
#  'owl': ['owl', 'http://dbpedia.org/resource/Owl'],
#  'peregrine falon': ['peregrine falcon',
#                      'http://dbpedia.org/resource/Peregrine_falcon'],
#  'pipit': ['pipit', 'http://dbpedia.org/resource/Pipit'],
#  'red kite': ['red kite', 'http://dbpedia.org/resource/Red_kite'],
#  'redlegged thrush': ['red-legged thrush',
#                       'http://dbpedia.org/resource/Red-legged_thrush'],
#  'redwing': ['redwing', 'http://dbpedia.org/resource/Redwing'],
#  'richard’s pipit': ["richard's pipit",
#                      "http://dbpedia.org/resource/Richard's_pipit"],
#  'sardinian warbler': ['sardinian warbler',
#                        'http://dbpedia.org/resource/Sardinian_warbler'],
#  'seabirds': ['seabird', 'http://dbpedia.org/resource/Seabird'],
#  'shearwater': ['shearwater', 'http://dbpedia.org/resource/Shearwater'],
#  'shorttoed snakeeagles as': ['short-toed snake eagle',
#                               'http://dbpedia.org/resource/Short-toed_snake_eagle'],
#  'slenderbilled gulls': ['slender-billed gull',
#                          'http://dbpedia.org/resource/Slender-billed_gull'],
#  'song thrush': ['song thrush', 'http://dbpedia.org/resource/Song_thrush'],
#  'species': ['species:', 'http://dbpedia.org/resource/Ludiortyx'],
#  'species i': ['species:', 'http://dbpedia.org/resource/Ludiortyx'],
#  'taiwan thrush': ['taiwan thrush',
#                    'http://dbpedia.org/resource/Taiwan_thrush'],
#  'this bird': ['atthis (bird)', 'http://dbpedia.org/resource/Atthis_(bird)'],
#  'vultures': ['vulture', 'http://dbpedia.org/resource/Vulture'],
#  'water pipit': ['water pipit', 'http://dbpedia.org/resource/Water_pipit'],
#  'water rails': ['water rail', 'http://dbpedia.org/resource/Water_rail'],
#  'white on': ['white lion', 'http://dbpedia.org/resource/White_lion'],
#  'white wagtail': ['white wagtail',
#                    'http://dbpedia.org/resource/White_wagtail'],
#  'yellowlegged gulls': ['yellow-legged gull',
#                         'http://dbpedia.org/resource/Yellow-legged_gull'],
#  '“scopoli’s” shearwater': ["scopoli's shearwater",
#                             "http://dbpedia.org/resource/Scopoli's_shearwater"]}
#
# ----------------------------------------
#
# {'a peruvian divingpetrel': ['peruvian diving petrel',
#                              'http://dbpedia.org/resource/Peruvian_diving_petrel'],
#  'andean avocets': ['andean avocet',
#                     'http://dbpedia.org/resource/Andean_avocet'],
#  'andean cockoftherock': ['guianan cock-of-the-rock',
#                           'http://dbpedia.org/resource/Guianan_cock-of-the-rock'],
#  'avocets': ['avocet', 'http://dbpedia.org/resource/Avocet'],
#  'bluefooted boobies': ['blue-footed booby',
#                         'http://dbpedia.org/resource/Blue-footed_booby'],
#  'blueheaded parrots': ['blue-headed parrot',
#                         'http://dbpedia.org/resource/Blue-headed_parrot'],
#  'chestnutcrested cotinga': ['chestnut-crested cotinga',
#                              'http://dbpedia.org/resource/Chestnut-crested_cotinga'],
#  'cinclodes': ['cinclodes', 'http://dbpedia.org/resource/Cinclodes'],
#  'cinclodes a': ['cinclodes', 'http://dbpedia.org/resource/Cinclodes'],
#  'cockoftherock': ['cock-of-the-rock',
#                    'http://dbpedia.org/resource/Cock-of-the-rock'],
#  'collared inca': ['collared inca',
#                    'http://dbpedia.org/resource/Collared_inca'],
#  'dacnis': ['dacnis', 'http://dbpedia.org/resource/Dacnis'],
#  'eagle': ['eagle', 'http://dbpedia.org/resource/Eagle'],
#  'elaenia': ['elaenia', 'http://dbpedia.org/resource/Elaenia'],
#  'green honeycreeper': ['green honeycreeper',
#                         'http://dbpedia.org/resource/Green_honeycreeper'],
#  'gulls': ['gull', 'http://dbpedia.org/resource/Gull'],
#  'hoatzin': ['hoatzin', 'http://dbpedia.org/resource/Hoatzin'],
#  'honeycreeper': ['honeycreeper', 'http://dbpedia.org/resource/Honeycreeper'],
#  'hooded mountain tanagers': ['hooded mountain tanager',
#                               'http://dbpedia.org/resource/Hooded_mountain_tanager'],
#  'humboldt penguin': ['humboldt penguin',
#                       'http://dbpedia.org/resource/Humboldt_penguin'],
#  'hummingbird': ['hummingbird', 'http://dbpedia.org/resource/Hummingbird'],
#  'inca terns': ['inca tern', 'http://dbpedia.org/resource/Inca_tern'],
#  'lyretailed nightjar': ['silky-tailed nightjar',
#                          'http://dbpedia.org/resource/Silky-tailed_nightjar'],
#  'macaws': ['macaw', 'http://dbpedia.org/resource/Macaw'],
#  'nighthawk': ['nighthawk', 'http://dbpedia.org/resource/Nighthawk'],
#  'owl': ['owl', 'http://dbpedia.org/resource/Owl'],
#  'parrot': ['parrot', 'http://dbpedia.org/resource/Parrot'],
#  'pelicans': ['pelican', 'http://dbpedia.org/resource/Pelican'],
#  'peruvian thickknees': ['peruvian thick-knee',
#                          'http://dbpedia.org/resource/Peruvian_thick-knee'],
#  'puna plover': ['puna plover', 'http://dbpedia.org/resource/Puna_plover'],
#  'purple sandpiper': ['purple sandpiper',
#                       'http://dbpedia.org/resource/Purple_sandpiper'],
#  'rednecked phalaropes': ['red-necked phalarope',
#                           'http://dbpedia.org/resource/Red-necked_phalarope'],
#  'sandcolored nighthawks': ['sand-coloured nighthawk',
#                             'http://dbpedia.org/resource/Sand-coloured_nighthawk'],
#  'seabird': ['seabird', 'http://dbpedia.org/resource/Seabird'],
#  'shearwaters': ['shearwater', 'http://dbpedia.org/resource/Shearwater'],
#  'shining sunbeam': ['shining sunbeam',
#                      'http://dbpedia.org/resource/Shining_sunbeam'],
#  'solitary eagle': ['solitary eagle',
#                     'http://dbpedia.org/resource/Solitary_eagle'],
#  'sooty shearwaters': ['sooty shearwater',
#                        'http://dbpedia.org/resource/Sooty_shearwater'],
#  'species': ['species:', 'http://dbpedia.org/resource/Ludiortyx'],
#  'terns': ['tern', 'http://dbpedia.org/resource/Tern'],
#  'trogons': ['trogon', 'http://dbpedia.org/resource/Trogon'],
#  'whitethroated toucan': ['white-throated toucan',
#                           'http://dbpedia.org/resource/White-throated_toucan'],
#  'wirecrested thorntail': ['wire-crested thorntail',
#                            'http://dbpedia.org/resource/Wire-crested_thorntail'],
#  'yellowbellied dacnis': ['yellow-bellied dacnis',
#                           'http://dbpedia.org/resource/Yellow-bellied_dacnis'],
#  'yellowbrowed sparrows': ['yellow-browed sparrow',
#                            'http://dbpedia.org/resource/Yellow-browed_sparrow']}
#
# ----------------------------------------
#
# {'collared sparrowhawk': ['collared sparrowhawk',
#                           'http://dbpedia.org/resource/Collared_sparrowhawk'],
#  'house sparrows': ['house sparrow',
#                     'http://dbpedia.org/resource/House_sparrow'],
#  'musk lorikeet': ['musk lorikeet',
#                    'http://dbpedia.org/resource/Musk_lorikeet'],
#  'parrots': ['parrot', 'http://dbpedia.org/resource/Parrot'],
#  'purplecrowned lorikeet': ['purple-crowned lorikeet',
#                             'http://dbpedia.org/resource/Purple-crowned_lorikeet'],
#  'rainbow lorikeet': ['rainbow lorikeet',
#                       'http://dbpedia.org/resource/Rainbow_lorikeet'],
#  'species': ['species:', 'http://dbpedia.org/resource/Ludiortyx']}
#
# ----------------------------------------
#
# {'budgerigars': ['budgerigar', 'http://dbpedia.org/resource/Budgerigar'],
#  'lovebird': ['ovenbird', 'http://dbpedia.org/resource/Ovenbird'],
#  'rosyfaced lovebird': ['rosy-faced lovebird',
#                         'http://dbpedia.org/resource/Rosy-faced_lovebird'],
#  'species': ['species:', 'http://dbpedia.org/resource/Ludiortyx']}
#
# ----------------------------------------
#
# {'australian ringneck': ['australian ringneck',
#                          'http://dbpedia.org/resource/Australian_ringneck'],
#  'beautiful bird': ['beautiful sunbird',
#                     'http://dbpedia.org/resource/Beautiful_sunbird'],
#  'many honeyeaters': ["mayr's honeyeater",
#                       "http://dbpedia.org/resource/Mayr's_honeyeater"],
#  'parrot': ['parrot', 'http://dbpedia.org/resource/Parrot'],
#  'species': ['species:', 'http://dbpedia.org/resource/Ludiortyx']}
#
# ----------------------------------------

# %% [markdown]
# Es un proceso computacionalmente costoso, pero podemos ver que da buenos resultados. Si nos fijamos, la inmensa mayoría de ellos son correctos salvo algunas excepciones que deberían ser eliminadas posteriormente.

# %% [markdown]
# # Ontología

# %% [markdown]
# En este apartado organizaremos los resultados en una ontología que posteriormente podrá ser abierta en *Protegé*.

# %%
from owlready2 import *

onto = get_ontology("http://test.org/trabajo_pajaros.owl")
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %% [markdown]
# La estructura será muy básica:
#
# - Cada pájaro será una individual asociado por la propiedad *IS_MENTIONED_BY* con su correspondiente publicación y por *DBPEDIA_URL* con su enlace de la Dbpedia.
# - Cada publicación tendrá asociados todos los pájaros que menciona mediante la propiedad *MENTIONS*, el enlace del blog de donde se extrajo mediante *PUBLICATION_URL* y su fecha a partir de *PUBLICATION_DATE*.

# %%
with onto:
    class Bird(Thing):
             pass
    class Publication(Thing):
            pass
    class Dbpedia(Thing):
        pass
    
    class Pub_url(Thing):
        pass
    
    class IS_MENTIONED_BY(ObjectProperty):
            domain    = [Bird]
            range     = [Publication]
            
    class MENTIONS(ObjectProperty):
            domain    = [Publication]
            range     = [Bird]
    class DBPEDIA_URL(ObjectProperty):
            domain    = [Dbpedia]
            range     = [Bird]
            
    class PUBLICATION_URL(ObjectProperty):
        domain    = [Pub_url]
        range     = [Publication]
            
    class PUBLICATION_DATE(DataProperty):
        range     = [str]

# %% [markdown]
# Todo este bucle es para guardar los resultados dentro de la ontología:

# %%
for ind,result in enumerate(results):
    
    text=open(data.publications[ind],"r",encoding="utf-8").read().split("---")
    
    date=text[0].translate(str.maketrans("","","\n")).translate(str.maketrans(" ","_","_"))
    url=text[1].translate(str.maketrans("","","\n"))
    
    pub = Publication(data.publications[ind])
    url=Pub_url(url)
    
    
    pub.PUBLICATION_URL.append(url)
    pub.PUBLICATION_DATE=[date]
    
    for key in result[0].keys():
        
        my_bird = Bird(result[0][key][0].translate(str.maketrans(" ","_","_")))
        
        bird_url=Dbpedia(result[0][key][1])        
        bird_url.label=result[0][key][1]
        
        my_bird.IS_MENTIONED_BY.append(pub)
        
        my_bird.DBPEDIA_URL.append(bird_url)
        
        pub.MENTIONS.append(my_bird)

# %% [markdown]
# Guardamos la ontología:

# %%
onto.save(file="birds_ontology.xml", format = "rdfxml")
